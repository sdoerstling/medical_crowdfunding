# %% [markdown]
# ### Import dependencies

# %%
import os
import json
import pandas as pd
import numpy as np
import sqlite3
import json
import copy
import re
import operator
import math

# %% [markdown]
# ### Import data

# %%
er = pd.read_csv('Comparing algorithms/er_for_eval.csv')

# %%
combinations = pd.read_csv('Comparing algorithms/model_combinations.csv')

# %% [markdown]
# ### Clean data

# %%
er['score'] = [1 if x is not np.nan else 0 for x in er['target_text']]

# %% [markdown]
# ### Run model evaluation

# %%
def GetCombos(combinations):
    '''
    input: pandas dataframe of model combinations
    output: list of lists of strings, each sub-list specifies a different 
          combination of model components
    '''

    #define results container
    r = []

    #create list of lists
    for i in range(len(combinations)):
        r.append(combinations.iloc[i].tolist())

    #return results
    return r

# %%
def ModelEval(er, combinations):

    combos = GetCombos(combinations)

    input_docs = []
    ner_terms_count = []
    docs_with_no_ner = []
    ner_terms_per_doc_mean = []
    ner_terms_per_doc_sd = []
    er_confidence_mean = []
    er_distance_mean = []

    for combo in combos:
        df = er.loc[(er['ner_model'] == combo[0]) & (er['doc_reconstruction'] == combo[1]) & (er['sent_embeddings'] == combo[2]) & (er['er_model'] == combo[3]),]

        #number of input dociments
        input_docs.append(50)

        #number of NAs for NER terms
        num_na = df['target_text'].isna().sum()

        #total number of NER terms
        ner_terms_count.append(df.shape[0] - num_na)

        #NER terms by document
        ner_by_url = df[['url','score']].groupby('url').agg('sum')
        docs_with_no_ner.append(pd.Series(ner_by_url['score'] == 0).sum())
        ner_terms_per_doc_mean.append(ner_by_url['score'].mean())
        ner_terms_per_doc_sd.append(ner_by_url['score'].std())

        #ER metrics
        er_confidence_mean.append(df['confidence'].astype(float).mean())
        er_distance_mean.append(df['distance'].astype(float).mean())

    r = pd.DataFrame({'input_docs':input_docs,
                    'ner_terms_count':ner_terms_count,
                    'docs_with_no_ner':docs_with_no_ner,
                    'ner_terms_per_doc_mean':ner_terms_per_doc_mean,
                    'ner_terms_per_doc_sd':ner_terms_per_doc_sd,
                    'er_confidence_mean':er_confidence_mean,
                    'er_distance_mean':er_distance_mean})
    return pd.concat([combinations, r], axis=1)

# %%
ModelEval(er, combinations)
# Out:
#        ner_model doc_reconstruction               embeddings  \
# 0   ner_clinical               none                     none
# 1   ner_clinical         concat_and                     none
# 2   ner_clinical      sent_with_ner                     none
# 3   ner_clinical               none  sbiobert_base_cased_mli
# 4   ner_clinical         concat_and  sbiobert_base_cased_mli
# 5   ner_clinical      sent_with_ner  sbiobert_base_cased_mli
# 6        ner_jsl               none                     none
# 7        ner_jsl         concat_and                     none
# 8        ner_jsl      sent_with_ner                     none
# 9        ner_jsl               none  sbiobert_base_cased_mli
# 10       ner_jsl         concat_and  sbiobert_base_cased_mli
# 11       ner_jsl      sent_with_ner  sbiobert_base_cased_mli
# 12  ner_diseases               none                     none
# 13  ner_diseases         concat_and                     none
# 14  ner_diseases      sent_with_ner                     none
# 15  ner_diseases               none  sbiobert_base_cased_mli
# 16  ner_diseases         concat_and  sbiobert_base_cased_mli
# 17  ner_diseases      sent_with_ner  sbiobert_base_cased_mli
#
#               entity_resolution_model  input_docs  ner_terms_count  \
# 0       chunkresolve_icd10cm_clinical          50              437
# 1       chunkresolve_icd10cm_clinical          50              413
# 2       chunkresolve_icd10cm_clinical          50              923
# 3   sbiobertresolve_icd10cm_augmented          50              437
# 4   sbiobertresolve_icd10cm_augmented          50              413
# 5   sbiobertresolve_icd10cm_augmented          50              923
# 6       chunkresolve_icd10cm_clinical          50              113
# 7       chunkresolve_icd10cm_clinical          50              103
# 8       chunkresolve_icd10cm_clinical          50              204
# 9   sbiobertresolve_icd10cm_augmented          50              113
# 10  sbiobertresolve_icd10cm_augmented          50              103
# 11  sbiobertresolve_icd10cm_augmented          50              204
# 12      chunkresolve_icd10cm_clinical          50              316
# 13      chunkresolve_icd10cm_clinical          50              266
# 14      chunkresolve_icd10cm_clinical          50              680
# 15  sbiobertresolve_icd10cm_augmented          50              316
# 16  sbiobertresolve_icd10cm_augmented          50              266
# 17  sbiobertresolve_icd10cm_augmented          50              680
#
#     docs_with_no_ner  ner_terms_per_doc_mean  ner_terms_per_doc_sd  \
# 0                  3                    8.74             10.866180
# 1                  3                    8.26             10.538191
# 2                  3                   18.46             31.883212
# 3                  3                    8.74             10.866180
# 4                  3                    8.26             10.538191
# 5                  3                   18.46             31.883212
# 6                 16                    2.26              3.983691
# 7                 16                    2.06              3.924855
# 8                 16                    4.08             10.703499
# 9                 16                    2.26              3.983691
# 10                16                    2.06              3.924855
# 11                16                    4.08             10.703499
# 12                 5                    6.32              8.574856
# 13                 6                    5.32              6.911806
# 14                 5                   13.60             25.385196
# 15                 5                    6.32              8.574856
# 16                 6                    5.32              6.911806
# 17                 5                   13.60             25.385196
#
#     er_confidence_mean  er_distance_mean
# 0             0.062511          1.015560
# 1             0.065614          0.963053
# 2             0.063406          0.972786
# 3             0.375657          6.381022
# 4             0.436572          5.756073
# 5             0.404267          6.015442
# 6             0.066368          0.580966
# 7             0.066749          0.566989
# 8             0.066055          0.596892
# 9             0.724112          3.072292
# 10            0.730066          2.949402
# 11            0.730880          2.932496
# 12            0.063051          0.884236
# 13            0.065686          0.782309
# 14            0.064172          0.850140
# 15            0.422962          5.939353
# 16            0.495769          5.210720
# 17            0.465946          5.471773

# %% [markdown]
# ### Which campaigns have >2x NER terms with sent_with_ner

# %%
df = er.loc[(er['ner_model'] == 'ner_clinical') & (er['doc_reconstruction'] == 'none') & (er['sent_embeddings'] == 'sbiobert_base_cased_mli') & (er['er_model'] == 'sbiobertresolve_icd10cm_augmented'),]

# %%
df[['url','score']].groupby('url').agg('sum')
# Out:
#                                                     score
# url
# https://www.gofundme.com/f/22iq896m5c                   0
# https://www.gofundme.com/f/2bkkgaq4                     6
# https://www.gofundme.com/f/2hp65afg                    10
# 1860  https://www.gofundme.com/f/2bkkgaq4  ner_clinical               none
#
#               sent_embeddings                           er_model  \
# 1855  sbiobert_base_cased_mli  sbiobertresolve_icd10cm_augmented
# 1856  sbiobert_base_cased_mli  sbiobertresolve_icd10cm_augmented
# 1857  sbiobert_base_cased_mli  sbiobertresolve_icd10cm_augmented
# 1858  sbiobert_base_cased_mli  sbiobertresolve_icd10cm_augmented
# 1859  sbiobert_base_cased_mli  sbiobertresolve_icd10cm_augmented
# 1860  sbiobert_base_cased_mli  sbiobertresolve_icd10cm_augmented
#
#                    target_text  sentence  start_char  end_char  \
# 1855       infantile Scoliosis       0.0       152.0     170.0
# 1856     a recent growth spurt       1.0       238.0     258.0
# 1857  derasticaly more serious       2.0       279.0     302.0
# 1858             the curvature       3.0       308.0     320.0
# 1859                   extreme       4.0       333.0     339.0
# 1860               loose faith       5.0      1578.0    1588.0
#
#                                     resolved_text entity_code  confidence  \
# 1855  spondylodysplasia, torrance type (disorder)        Q788      0.1253
# 1856                           recent weight gain        R635      0.7366
# 1857                   excessive smegma (finding)        N488      0.0861
# 1858                           curvature of spine       M4399      0.2996
# 1859                                   exuberance        R468      0.0813
# 1860                            negative attitude       R4589      0.1606
#
#       distance  score
# 1855    8.8018      1
# 1856    8.6517      1
# 1857    9.1094      1
# 1858    7.3941      1
# 1859    8.2304      1
# 1860    5.7164      1

# %%
df2 = er.loc[(er['ner_model'] == 'ner_diseases') & (er['doc_reconstruction'] == 'none') & (er['sent_embeddings'] == 'sbiobert_base_cased_mli') & (er['er_model'] == 'sbiobertresolve_icd10cm_augmented'),]

# %%
df2[['url','score']].groupby('url').agg('sum')
# Out:
#                                                     score
# url
# https://www.gofundme.com/f/22iq896m5c                   0
# https://www.gofundme.com/f/2bkkgaq4                     3
# https://www.gofundme.com/f/2hp65afg                     7
# https://www.gofundme.com/f/2phb83rg                     1
# https://www.gofundme.com/f/3s01f0o                      3
# https://www.gofundme.com/f/5cv535-cancer-treatm...      8
# https://www.gofundme.com/f/5q5oals                      3
# https://www.gofundme.com/f/FergusonK9Health             1
# https://www.gofundme.com/f/Jacobseye                    2
# https://www.gofundme.com/f/JosiahAnakinLopez            0
# https://www.gofundme.com/f/JustinWeber                  0
# https://www.gofundme.com/f/Kayataskidsclinic            3
# https://www.gofundme.com/f/LauraLymeTreatment           9
# https://www.gofundme.com/f/SavingTyisha                12
# https://www.gofundme.com/f/TruverFamily                 4
# https://www.gofundme.com/f/aLittleYoga                  9
# https://www.gofundme.com/f/angel-sarah-forever-...      1
# https://www.gofundme.com/f/aydens-miracle               4
# https://www.gofundme.com/f/b925sc                       7
# https://www.gofundme.com/f/billbrownlv                  4
# https://www.gofundme.com/f/cheyennejensen               2
# https://www.gofundme.com/f/co1efs                       2
# https://www.gofundme.com/f/coach-chucks-livingm...      4
# https://www.gofundme.com/f/fzwoa8                       8
# https://www.gofundme.com/f/ginny-thompson-needs...     12
# https://www.gofundme.com/f/help-piper-afford-a-...      3
# https://www.gofundme.com/f/helpsarahbanning             1
# https://www.gofundme.com/f/jenniferwright               3
# https://www.gofundme.com/f/k9v7rvss                     5
# https://www.gofundme.com/f/lindsey-and-adam-dia...      1
# https://www.gofundme.com/f/living-expensesmedic...      4
# https://www.gofundme.com/f/lmagan                      32
# https://www.gofundme.com/f/m5mzoc                       6
# https://www.gofundme.com/f/mariah-gibson-trauma...      1
# https://www.gofundme.com/f/mdr5e-medical-expens...      2
# https://www.gofundme.com/f/new-eye-prostheses           7
# https://www.gofundme.com/f/new-partial-for-my-wife      3
# https://www.gofundme.com/f/nmcs6-jacks-medical-...     29
# https://www.gofundme.com/f/pawpawgaines                 5
# https://www.gofundme.com/f/quotlife-saving-surg...      6
# https://www.gofundme.com/f/romeos-medical-care          8
# https://www.gofundme.com/f/ruths-skin-removal-s...      9
# https://www.gofundme.com/f/tangopolly                  10
# https://www.gofundme.com/f/teamjoc                     47
# https://www.gofundme.com/f/weregoingtofight-bob...     15
# https://www.gofundme.com/f/wesley-needs-a-liver...      2
# https://www.gofundme.com/f/xm4c4cq7q                    2
# https://www.gofundme.com/f/xqs55f7                      6
# https://www.gofundme.com/f/ytky34r8                     0
# https://www.gofundme.com/f/z33htt-ayudame-a-cam...      0

# %%
df2[df2['url'] == 'https://www.gofundme.com/f/3s01f0o']
# Out:
#                                      url     ner_model doc_reconstruction  \
# 5928  https://www.gofundme.com/f/3s01f0o  ner_diseases               none
# 5929  https://www.gofundme.com/f/3s01f0o  ner_diseases               none
# 5930  https://www.gofundme.com/f/3s01f0o  ner_diseases               none
#
#               sent_embeddings                           er_model  \
# 5928  sbiobert_base_cased_mli  sbiobertresolve_icd10cm_augmented
# 5929  sbiobert_base_cased_mli  sbiobertresolve_icd10cm_augmented
# 5930  sbiobert_base_cased_mli  sbiobertresolve_icd10cm_augmented
#
#                       target_text  sentence  start_char  end_char  \
# 5928                a swollen arm       0.0       240.0     252.0
# 5929  a blood clot near his heart       1.0       283.0     309.0
# 5930               the blood clot       2.0       470.0     483.0
#
#                             resolved_text entity_code  confidence  distance  \
# 5928                         swollen legs       M7989      0.2274    5.7004
# 5929  exposure to blood and/or body fluid         X58      0.1235   10.5322
# 5930          blood clot in eye (finding)        H578      0.2178    8.0489
#
#       score
# 5928      1
# 5929      1
# 5930      1

# %% [markdown]
# # Conclusions
# - I coded something wrong with the "sent_with_ner" document reconstruction, so there are not actually >2x the amount of NER terms
# - However, document reconstructions do not seem to meaningfully impact finding NER terms or entity resolution, so we will use the original.
# - "ner_clinical" identifies too many superfluous terms.
# - "ner_diseases" seems to pick up important information with minimal superfluous terms
# - biobert resolution will work the best
#
#
# ### Final approach
# - NER: ner_diseases
# - no document reconstruction
# - sbiobert embeddings and entity resolution
