# %%
import pandas as pd
from sklearn.metrics import cohen_kappa_score

# %%
import os
os.getcwd()
# Out:
# '/Users/sd363/Desktop/crowdfunding'

# %%
df = pd.read_csv('Super earners/qualtrics/responses/1_28_2021_ada_anu.csv')

# %%
df.loc[:,'qid'] = [x.split('-')[0] for x in df['question_id']]

# %%
df['qid'].unique()
# Out:
# array(['individual_or_organization', 'links_external', 'appeals',
#        'author_relationship', 'patient_culpability', 'age', 'gender',
#        'family_role', 'career', 'career_notes',
#        'positive_char_ref_patient', 'positive_char_ref_other',
#        'insurance', 'mention_funds', 'non_medical_funds', 'medical_funds',
#        'other_funds', 'notes'], dtype=object)

# %%
def Agreement(l1,l2):
    correct = 0
    for i in range(len(l1)):
        if l1[i] == l2[i]:
            correct = correct + 1
        else:
            continue
    return correct/len(l1)

# %%
r = []
qs = [
    'individual_or_organization',
    'links_external',
    'appeals',
    'author_relationship',
    'patient_culpability',
    'age',
    'gender',
    'career',
    'positive_char_ref_patient',
    'positive_char_ref_other',
    'insurance',
    'mention_funds',
    'other_funds'
    
]
for q in qs:
    d = df[df['qid'] == q]
    r1 = d['rater_1'].tolist()
    r2 = d['rater_2'].tolist()
    ck = cohen_kappa_score(r1,r2)
    agreement = Agreement(r1,r2)
    r.append({'qid':q, 'ck': ck, 'agr': agreement})
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:604: RuntimeWarning: invalid value encountered in true_divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)

# %%
pd.DataFrame(r)
# Out:
#                            qid        ck   agr
# 0   individual_or_organization       NaN  1.00
# 1               links_external  0.827586  0.95
# 2                      appeals  0.875000  0.95
# 3          author_relationship  0.861111  0.90
# 4          patient_culpability       NaN  1.00
# 5                          age  0.701493  0.90
# 6                       gender  1.000000  1.00
# 7                       career  0.615385  0.80
# 8    positive_char_ref_patient  0.693487  0.80
# 9      positive_char_ref_other  0.733333  0.90
# 10                   insurance  0.830508  0.90
# 11               mention_funds -0.052632  0.90
# 12                 other_funds  0.375000  0.80

# %%
med_funds = df[df['qid'] == 'non_medical_funds'].fillna(' ')

# %%
med_funds.head()
# Out:
#             question_id                                      question_text  \
# 14    non_medical_funds  Does the campaign describe intended use of fun...
# 32  non_medical_funds-1  Does the campaign describe intended use of fun...
# 50  non_medical_funds-2  Does the campaign describe intended use of fun...
# 68  non_medical_funds-3  Does the campaign describe intended use of fun...
# 86  non_medical_funds-4  Does the campaign describe intended use of fun...
#
#                                               rater_1  \
# 14                       Accounting for lost earnings
# 32                                                NaN
# 50  Does not mention non-medical expenses or finan...
# 68  Does not mention non-medical expenses or finan...
# 86  Travel,Other non-medical expense (not otherwis...
#
#                                               rater_2                qid
# 14  Travel,Other non-medical expense (not otherwis...  non_medical_funds
# 32  Does not mention non-medical expenses or finan...  non_medical_funds
# 50  Does not mention non-medical expenses or finan...  non_medical_funds
# 68  Does not mention non-medical expenses or finan...  non_medical_funds
# 86  Does not mention non-medical expenses or finan...  non_medical_funds

# %%
med_funds.loc[:,'rater_1_clean'] = [x.split(',') for x in med_funds['rater_1']]

# %%
med_funds.loc[:,'rater_2_clean'] = [x.split(',') for x in med_funds['rater_2']]

# %%
#convert data from wide to long
rater_1 = pd.melt(med_funds, id_vars=['question_id'], value_vars=['rater_1_clean']).explode('value')
rater_2 = pd.melt(med_funds, id_vars=['question_id'], value_vars=['rater_2_clean']).explode('value')

# %%
melt = pd.concat([rater_1, rater_2])

# %%
melt = melt.rename(columns={'variable':'rater','value':'cat'})
melt = melt.reset_index()
del melt['index']

# %%
def comma2lofd(df):
    '''convert cat column from comma delimited to list of dictionaries with 1 or 0 for each category'''
    
#     disease_categories = [
#         'Medical expenses - partly covered by insurance',
#         'Medial expenses - not covered by insurance',
#         'Medical expenses - no mention of insurance coverage',
#         'Does not mention medical expeneses or financial burden'
#     ]

    disease_categories = [
        'Accounting for lost earnings',
        'Travel',
        'Does not mention non-medical expenses or financial burden',
        'Other non-medical expense (not otherwise specified)',
        'Child care'
    ]
    
    r = []
    
    for index,row in df.iterrows():
        lofd = []
        as_list = row['cat'].split(',')
        for disease in disease_categories:
            if disease in as_list:
                lofd.append({disease:1})
            else:
                lofd.append({disease:0})
        r.append(lofd)
    return r

# %%
melt['lofd'] = comma2lofd(melt)
del melt['cat']

# %%
long = melt.explode('lofd')

# %%
long.insert(loc=2, column='cat', value=[list(x.items())[0][0] for x in long['lofd']])
long.insert(loc=3, column='count', value=[list(x.items())[0][1] for x in long['lofd']])

# %%
rater_1_pivot = long[long['rater'] == 'rater_1_clean'].pivot_table(index=['question_id'], columns='cat', values='count', aggfunc=(pd.Series.sum), fill_value=0)

# %%
rater_2_pivot = long[long['rater'] == 'rater_2_clean'].pivot_table(index=['question_id'], columns='cat', values='count', aggfunc=(pd.Series.sum), fill_value=0)

# %%
cat = []
cohens_kappa = []
percent_agreement = []
for col in rater_1_pivot.columns:
    cat.append(col)
    cohens_kappa.append(cohen_kappa_score(rater_1_pivot[col], rater_2_pivot[col]))
    percent_agreement.append(Agreement(rater_1_pivot[col], rater_2_pivot[col]))
kappa_df = pd.DataFrame({'category':cat, 
              'cohens kappa':cohens_kappa,
              'agr':percent_agreement})
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:604: RuntimeWarning: invalid value encountered in true_divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)

# %%
kappa_df
# Out:
#                                             category  cohens kappa  agr
# 0                       Accounting for lost earnings      0.230769  0.8
# 1                                         Child care           NaN  1.0
# 2  Does not mention non-medical expenses or finan...      0.200000  0.6
# 3  Other non-medical expense (not otherwise speci...      0.529412  0.8
# 4                                             Travel      0.230769  0.8

# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from time import sleep
import requests 
import re
import json



page = requests.get("https://www.gofundme.com/f/eric-stevens-care-trust")

soup = BeautifulSoup(page.content, 'html.parser')

all_scripts = soup.find_all('script')
txt = all_scripts[0].get_text()
data = json.loads(re.findall(r'window\.initialState = ({.*?});', txt)[0])

# %%
data
# Out:
# {'auth': {'captchaRequired': False,
#   'captchaValid': False,
#   'captchaValidating': False,
#   'email': {'error': {}, 'status': 'default'},
#   'facebook': {'error': {}, 'status': 'default'},
#   'isAuthenticated': False},
#  'bigweb': {'contact': {'actions': [],
#    'chatAudience': 1,
#    'chatReady': False,
#    'chatStatus': 'offline',
#    'chatWindow': 'closed',
#    'emailAudience': 0,
#    'isLoadingActions': False,
#    'selected': [0],
#    'suggestions': {}}},
#  'co': {'createComment': {'media': []},
#   'donationReceipt': {'amount': 0,
#    'currencyCode': '',
#    'donor': {'email': '', 'firstName': '', 'isAnonymous': True, 'name': ''},
#    'signedDonationId': ''},
#   'postDonateCreateComment': {'error': False,
#    'loading': False,
#    'media': [],
#    'mediaError': []},
#   'teamEmailInvites': {'error': False,
#    'field_errors': {},
#    'invitation_count': 0,
#    'loading': False},
#   'teamInvitations': {}},
#  'facebook': {'email': '',
#   'facebookId': '',
#   'facebookToken': '',
#   'first_name': '',
#   'last_name': '',
#   'meta': {'error': {}, 'status': 'default'}},
#  'feed': {'campaign': {'id': 51640210,
#    'campaign_id': 51640210,
#    'auto_fb_post_mode': False,
#    'has_beneficiary': True,
#    'beneficiary': {'id': 41913950,
#     'user_id': 41913950,
#     'person_id': 203606078,
#     'first_name': 'Eric',
#     'last_name': 'Stevens',
#     'is_placeholder_bene': False,
#     'profile_url': ''},
#    'category_id': 11,
#    'charity_id': 0,
#    'is_charity': False,
#    'charity': {},
#    'currencycode': 'USD',
#    'current_amount': 1233590,
#    'default_url': 'eric-stevens-team-stevens-nation',
#    'donation_count': 5645,
#    'comments_enabled': True,
#    'donations_enabled': True,
#    'has_donations': True,
#    'has_gfm_org_donation': False,
#    'fund_description': 'Our Little Brother Eric<br />I imagine seeing his future, taking his kids to a game at Cal Berkeley where we both played.\xa0<br />I imagine seeing his job as a firemen becoming a lifelong family and the career he hoped.\xa0<br />I imagine being there for when he and his wife celebrate their 25th anniversary and not just their first.\xa0<br />I imagine taking a walk with him around a house that has since become his home.\xa0<br />I imagine him teaching my kids about how great of a big brother I was and reminiscing with him about a simpler time.\xa0<br />Then I wake up from these dreams and the nightmare has just begun.\xa0<br /><img src="https://d2g8igdw686xgo.cloudfront.net/42600232_1570638495410822_r.jpeg" alt="42600232_1570638495410822_r.jpeg" width="100%" media_type="3" /><br /><img src="https://d2g8igdw686xgo.cloudfront.net/42600232_1570638525247916_r.jpeg" alt="42600232_1570638525247916_r.jpeg" width="100%" media_type="3" /><br /><img src="https://d2g8igdw686xgo.cloudfront.net/42600232_1570642542142990_r.jpeg" alt="42600232_1570642542142990_r.jpeg" width="100%" media_type="3" /><br /><br /><strong>Diagnosis ALS</strong><br /><br />When you are diagnosed with ALS you are forced to see the future before you and realize that all your dreams have vanished. \xa0That each day you must appreciate a basic skill before it has been taken from you. Life expectancy is 2-5 years and paralysis comes much sooner.<br /><br /><strong>Why does it happen?\xa0</strong><br /><br />We are still at the infancy of understanding this disease and there <strong>has not</strong> been any definitive cause. Can some point to the game of football with claims of cause, sure. But reality is, all you will be doing is grasping for an answer.\xa0<br />An answer that will never come.\xa0<br />I know my brother, I know he is a fighter and know he will bite his lip and fight!\xa0<br />As he sits up in the doctors chair, he asked <strong>“How do I fight it?”</strong><br />That is where the nightmare takes hold. Because there is even less answers to this question than the one of cause.\xa0<br />As an athlete you want a game plan, as a firemen you want a protocol, as a human you want hope! But right now all I can do is look at him and pray.\xa0<br /><br />Pray that he will be spared.\xa0<br /><br />Pray that he will enjoy each day<br /><br />Pray that he will know I will love him through all this.\xa0<br /><br />Today, I have no answer to WHY it happens or WHAT to do, but I do have an answer for HOW you and I can help!<br /><br />According to HuffPost.com, “ALS is a very expensive disease, costing patients an estimated $300,000 a year. The majority of patients bankrupt their families with the costs, and an even larger number simply can’t afford the cost to <strong>stay alive</strong>, so they don’t. Can you imagine - having to stop <strong>BEING ALIVE</strong> because it’s too expensive?”<br />All proceeds will go towards Eric’s treatment and care and will help raise awareness of ALS.<br />We are so grateful for everyone’s continued support.\xa0<br />The Stevens Family<br /><br />Learn more about Eric and his Battle to #axeALS at his Facebook page, Team Stevens Nation.<a href="https://m.facebook.com/groups/2339022646428073/?ref=group_header&amp;view=group"><br /></a><a href="https://www.facebook.com/groups/teamstevensnation/"><a href="https://www.facebook.com/groups/teamstevensnation/" target="_blank" class="" rel="nofollow noopener noreferrer">https://www.facebook.com/groups/teamstevensnation/</a></a><a href="https://m.facebook.com/groups/2339022646428073/?ref=group_header&amp;view=group">\xa0</a>',
#    'fund_description_excerpt': 'Our Little Brother EricI imagine seeing his future, taking his kids to a game at Cal … Craig Stevens needs your support for Eric Stevens (Team Stevens Nation)',
#    'fund_name': 'Eric Stevens (Team Stevens Nation)',
#    'goal_amount': 1500000,
#    'media_type': 3,
#    'project_type': 1,
#    'template_id': 0,
#    'turn_off_donations': 0,
#    'url': 'eric-stevens-team-stevens-nation',
#    'user_id': 41914034,
#    'user_first_name': 'Craig',
#    'user_last_name': 'Stevens',
#    'user_facebook_id': '114619606613074',
#    'user_profile_url': 'https://graph.facebook.com/v7.0/114619606613074/picture',
#    'media_id': '',
#    'visible_in_search': True,
#    'status': 1,
#    'deactivated': False,
#    'in_degraded_mode': False,
#    'state': 'active',
#    'is_launched': True,
#    'campaign_image_url': 'https://d2g8igdw686xgo.cloudfront.net/42600232_1570640521184863_r.jpeg',
#    'campaign_photo': {'url': 'https://d2g8igdw686xgo.cloudfront.net/42600232_1570640521184863_r.jpeg',
#     'scaled': {'4x3-1200': 'https://images.gofundme.com/1wG0cqKt_VKedHV_lyQfJzPqzTQ=/1200x900/https://d2g8igdw686xgo.cloudfront.net/42600232_1570640521184863_r.jpeg',
#      '3x2-1200': 'https://images.gofundme.com/3mDqn6Q1usqk3xFEpixIxM8sGCk=/1200x800/https://d2g8igdw686xgo.cloudfront.net/42600232_1570640521184863_r.jpeg',
#      '16x9-720': 'https://images.gofundme.com/6_8K_YBMwxZCl_Xz5l9Ka4bchT4=/720x405/https://d2g8igdw686xgo.cloudfront.net/42600232_1570640521184863_r.jpeg',
#      '3x2-720': 'https://images.gofundme.com/EPS0B3AGQrR7s3oLavsrZcIa_mQ=/720x480/https://d2g8igdw686xgo.cloudfront.net/42600232_1570640521184863_r.jpeg',
#      '3x2-640': 'https://images.gofundme.com/AICipCaBR2o4ev6i2InJnGc9Hic=/640x480/https://d2g8igdw686xgo.cloudfront.net/42600232_1570640521184863_r.jpeg',
#      '1x1-960': 'https://images.gofundme.com/W_u7FMg18p4yZLmMFbYnHgdIUIk=/960x960/https://d2g8igdw686xgo.cloudfront.net/42600232_1570640521184863_r.jpeg'}},
#    'created_at': '2020-10-02T17:46:05-05:00',
#    'launch_date': '2019-10-09T11:54:44-05:00',
#    'social_share_last_update': '2021-01-30T21:28:37-06:00',
#    'location': {'city': 'Los Angeles, CA',
#     'country': 'US',
#     'postal_code': '',
#     'state_prefix': 'CA'},
#    'tags': [],
#    'is_business': False,
#    'business': {},
#    'is_team': False,
#    'team': {},
#    'is_partner': False,
#    'partner': {}},
#   'comments': [],
#   'counts': {'amount_raised_unattributed': 0,
#    'campaign_hearts': 0,
#    'number_of_donations_unattributed': 0,
#    'social_share_total': 0,
#    'total_co_photos': 0,
#    'total_comments': 0,
#    'total_community_photos': 0,
#    'total_donations': 0,
#    'total_photos': 0,
#    'total_unique_donors': 0,
#    'total_updates': 0},
#   'donations': [{'donation_id': 686260940,
#     'uc_id': '32534363',
#     'amount': 5,
#     'is_offline': False,
#     'is_anonymous': True,
#     'created_at': '2021-01-30T14:28:37-06:00',
#     'name': 'Anonymous',
#     'profile_url': '',
#     'verified': True},
#    {'donation_id': 686169744,
#     'uc_id': '32517737',
#     'amount': 25,
#     'is_offline': False,
#     'is_anonymous': False,
#     'created_at': '2021-01-30T11:57:17-06:00',
#     'name': 'John  Allred',
#     'profile_url': '',
#     'verified': True},
#    {'donation_id': 685856314,
#     'uc_id': '32463802',
#     'amount': 100,
#     'is_offline': False,
#     'is_anonymous': False,
#     'created_at': '2021-01-29T20:33:16-06:00',
#     'name': 'Joey Toboni',
#     'profile_url': '',
#     'verified': True},
#    {'donation_id': 684909962,
#     'uc_id': '32278472',
#     'amount': 10,
#     'is_offline': False,
#     'is_anonymous': True,
#     'created_at': '2021-01-28T14:03:05-06:00',
#     'name': 'Anonymous',
#     'profile_url': '',
#     'verified': True},
#    {'donation_id': 684551394,
#     'uc_id': '32217831',
#     'amount': 20,
#     'is_offline': False,
#     'is_anonymous': False,
#     'created_at': '2021-01-27T23:01:23-06:00',
#     'name': 'Sue Hatfied',
#     'profile_url': '',
#     'verified': True},
#    {'donation_id': 683878216,
#     'uc_id': '32087460',
#     'amount': 30,
#     'is_offline': False,
#     'is_anonymous': True,
#     'created_at': '2021-01-26T21:59:40-06:00',
#     'name': 'Anonymous',
#     'profile_url': '',
#     'verified': True},
#    {'donation_id': 683874102,
#     'uc_id': '32086430',
#     'amount': 74,
#     'is_offline': False,
#     'is_anonymous': True,
#     'created_at': '2021-01-26T21:50:32-06:00',
#     'name': 'Anonymous',
#     'profile_url': '',
#     'verified': True},
#    {'donation_id': 682765808,
#     'uc_id': '31871701',
#     'amount': 50,
#     'is_offline': False,
#     'is_anonymous': False,
#     'created_at': '2021-01-25T07:12:30-06:00',
#     'name': 'Suzanne Miller Beard',
#     'profile_url': '',
#     'verified': True},
#    {'donation_id': 682532674,
#     'uc_id': '31836825',
#     'amount': 200,
#     'is_offline': False,
#     'is_anonymous': False,
#     'created_at': '2021-01-24T19:31:15-06:00',
#     'name': 'Cathryn Broderick',
#     'profile_url': '',
#     'verified': True},
#    {'donation_id': 681282458,
#     'uc_id': '31586599',
#     'amount': 50,
#     'is_offline': False,
#     'is_anonymous': False,
#     'created_at': '2021-01-22T15:09:48-06:00',
#     'name': 'Judy Rossman ',
#     'profile_url': '',
#     'verified': True},
#    {'donation_id': 681258308,
#     'uc_id': '31582147',
#     'amount': 200,
#     'is_offline': False,
#     'is_anonymous': False,
#     'created_at': '2021-01-22T14:33:59-06:00',
#     'name': 'Colleen Grosz',
#     'profile_url': '',
#     'verified': True},
#    {'donation_id': 680543620,
#     'uc_id': '31440502',
#     'amount': 100,
#     'is_offline': False,
#     'is_anonymous': False,
#     'created_at': '2021-01-21T12:11:01-06:00',
#     'name': "Katherine O'Brien/LIMGC",
#     'profile_url': '',
#     'verified': True},
#    {'donation_id': 680465826,
#     'uc_id': '31425123',
#     'amount': 25,
#     'is_offline': False,
#     'is_anonymous': False,
#     'created_at': '2021-01-21T09:49:01-06:00',
#     'name': 'David Whitinger',
#     'profile_url': '',
#     'verified': True},
#    {'donation_id': 680240622,
#     'uc_id': '31383694',
#     'amount': 50,
#     'is_offline': False,
#     'is_anonymous': False,
#     'created_at': '2021-01-20T20:26:08-06:00',
#     'name': 'Timothy Beatty',
#     'profile_url': '',
#     'verified': True},
#    {'donation_id': 680044012,
#     'uc_id': '31340651',
#     'amount': 500,
#     'is_offline': False,
#     'is_anonymous': False,
#     'created_at': '2021-01-20T13:59:05-06:00',
#     'name': 'Ryan Edwards',
#     'profile_url': '',
#     'verified': True},
#    {'donation_id': 679741236,
#     'uc_id': '31290692',
#     'amount': 250,
#     'is_offline': False,
#     'is_anonymous': False,
#     'created_at': '2021-01-19T22:17:35-06:00',
#     'name': 'Elizabeth Peterman',
#     'profile_url': '',
#     'verified': True},
#    {'donation_id': 678963898,
#     'uc_id': '31130037',
#     'amount': 25,
#     'is_offline': False,
#     'is_anonymous': False,
#     'created_at': '2021-01-18T15:40:41-06:00',
#     'name': 'Helen Alexander',
#     'profile_url': '',
#     'verified': True},
#    {'donation_id': 678867050,
#     'uc_id': '31112750',
#     'amount': 25,
#     'is_offline': False,
#     'is_anonymous': True,
#     'created_at': '2021-01-18T12:50:49-06:00',
#     'name': 'Anonymous',
#     'profile_url': '',
#     'verified': True},
#    {'donation_id': 678865086,
#     'uc_id': '31112395',
#     'amount': 75,
#     'is_offline': False,
#     'is_anonymous': False,
#     'created_at': '2021-01-18T12:47:29-06:00',
#     'name': 'Jill Muegge',
#     'profile_url': '',
#     'verified': True},
#    {'donation_id': 678800688,
#     'uc_id': '31099957',
#     'amount': 50,
#     'is_offline': False,
#     'is_anonymous': False,
#     'created_at': '2021-01-18T10:50:40-06:00',
#     'name': 'Rita Kemmerer ',
#     'profile_url': '',
#     'verified': True}],
#   'identity': [],
#   'photos': [],
#   'team_members': [],
#   'topDonations': [],
#   'updates': [],
#   'velocity': {'recent_donations': {'total': 0}}},
#  'form': {},
#  'meta': {'co': {'shortenedShareUtmUrls': {'SMS_ANDROID_SHARESHEET': {'CAMPAIGN_PAGE': {'error': False,
#       'initialized': False,
#       'loading': False},
#      'POSTCREATE_CAMPAIGN': {'error': False,
#       'initialized': False,
#       'loading': False},
#      'POSTDONATE_MODAL': {'error': False,
#       'initialized': False,
#       'loading': False}},
#     'EMAIL_ANDROID_SHARESHEET': {'CAMPAIGN_PAGE': {'error': False,
#       'initialized': False,
#       'loading': False},
#      'POSTCREATE_CAMPAIGN': {'error': False,
#       'initialized': False,
#       'loading': False},
#      'POSTDONATE_MODAL': {'error': False,
#       'initialized': False,
#       'loading': False}},
#     'PRINT_POSTER': {'CAMPAIGN_PAGE': {'error': False,
#       'initialized': False,
#       'loading': False},
#      'POSTCREATE_CAMPAIGN': {'error': False,
#       'initialized': False,
#       'loading': False},
#      'POSTDONATE_MODAL': {'error': False,
#       'initialized': False,
#       'loading': False}},
#     'COPY_LINK_ALL': {'CAMPAIGN_PAGE': {'error': False,
#       'initialized': False,
#       'loading': False},
#      'POSTDONATE_MODAL': {'error': False,
#       'initialized': False,
#       'loading': False}}}},
#   'feed': {'campaign': {'error': False,
#     'initialized': True,
#     'last_updated_at': '2021-02-01T15:33:39.765388-06:00',
#     'loading': False,
#     'statusCode': 200},
#    'comments': {'error': False,
#     'has_next': False,
#     'initialized': False,
#     'last_updated_at': '',
#     'loading': False},
#    'counts': {'error': False,
#     'initialized': False,
#     'last_updated_at': '',
#     'loading': False},
#    'donations': {'error': False,
#     'has_next': False,
#     'initialized': False,
#     'last_updated_at': '',
#     'loading': False},
#    'identity': {'error': False,
#     'has_next': False,
#     'initialized': False,
#     'last_updated_at': '',
#     'loading': False},
#    'photos': {'community': {'error': False,
#      'has_next': False,
#      'initialized': False,
#      'last_updated_at': '',
#      'loading': False},
#     'general': {'error': False,
#      'has_next': False,
#      'initialized': False,
#      'last_updated_at': '',
#      'loading': False},
#     'update': {'error': False,
#      'has_next': False,
#      'initialized': False,
#      'last_updated_at': '',
#      'loading': False}},
#    'team_members': {'error': False,
#     'initialized': False,
#     'last_updated_at': '',
#     'loading': False},
#    'topDonations': {'error': False,
#     'initialized': False,
#     'last_updated_at': '',
#     'loading': False},
#    'updates': {'error': False,
#     'has_next': False,
#     'initialized': False,
#     'last_updated_at': '',
#     'loading': False}},
#   'global': {'algolia': {'hitIndex': 'prod_funds',
#     'queryIndex': 'prod_funds_query_suggestions'},
#    'braintree': {'tokenizationKey': 'production_z3rcxp4m_jcv2q3j4xtt8r4zt'},
#    'country': 'US',
#    'domain': 'gofundme.com',
#    'facebook': {'appId': '407682420960',
#     'pages': ['299947508549', '455380344852029']},
#    'geoRecord': {'countryCode': 'US', 'isInEU': False, 'region': 'VA'},
#    'google': {'clientId': '915486944487-ivo3ng6it92lj44ka8ca7nro7o5kk3om.apps.googleusercontent.com'},
#    'locale': {'bcp47': 'en-US', 'iso15897': 'en_US'},
#    'publicPath': '/',
#    'reCaptcha': {'bigwebKey': '6LfSrgoUAAAAAOjFZdE2noWVcUL1GNSNV79IS6dv',
#     'siteKey': '6LfeQnMUAAAAAFZHYbbs4BqEsxSNrl9oQqwEBUAM'},
#    'redirect': {'originalUrl': '', 'redirectUrl': '', 'shouldRedirect': False},
#    'showCookieBanner': False,
#    'subdomains': ['www'],
#    'language': 'en'}},
#  'optimizely': {'version': '4',
#   'rollouts': [{'experiments': [{'status': 'Paused',
#       'audienceIds': [],
#       'variations': [{'variables': [],
#         'id': '15401000505',
#         'key': '15401000505',
#         'featureEnabled': False}],
#       'id': '15401450154',
#       'key': '15401450154',
#       'layerId': '15409120907',
#       'trafficAllocation': [{'entityId': '15401000505', 'endOfRange': 10000}],
#       'forcedVariations': {}}],
#     'id': '15409120907'},
#    {'experiments': [{'status': 'Running',
#       'audienceIds': [],
#       'variations': [{'variables': [],
#         'id': '15846910270',
#         'key': '15846910270',
#         'featureEnabled': True}],
#       'id': '15834650584',
#       'key': '15834650584',
#       'layerId': '15842440850',
#       'trafficAllocation': [{'entityId': '15846910270', 'endOfRange': 10000}],
#       'forcedVariations': {}}],
#     'id': '15842440850'},
#    {'experiments': [{'status': 'Not started',
#       'audienceIds': [],
#       'variations': [{'variables': [],
#         'id': '16494440181',
#         'key': '16494440181',
#         'featureEnabled': False}],
#       'id': '16484570297',
#       'key': '16484570297',
#       'layerId': '16506650013',
#       'trafficAllocation': [],
#       'forcedVariations': {}}],
#     'id': '16506650013'},
#    {'experiments': [{'status': 'Not started',
#       'audienceIds': [],
#       'variations': [{'variables': [],
#         'id': '16747670138',
#         'key': '16747670138',
#         'featureEnabled': False}],
#       'id': '16724490835',
#       'key': '16724490835',
#       'layerId': '16732750156',
#       'trafficAllocation': [],
#       'forcedVariations': {}}],
#     'id': '16732750156'},
#    {'experiments': [{'status': 'Not started',
#       'audienceIds': [],
#       'variations': [{'variables': [],
#         'id': '16775420298',
#         'key': '16775420298',
#         'featureEnabled': False}],
#       'id': '16765421172',
#       'key': '16765421172',
#       'layerId': '16753900914',
#       'trafficAllocation': [],
#       'forcedVariations': {}}],
#     'id': '16753900914'},
#    {'experiments': [{'status': 'Not started',
#       'audienceIds': [],
#       'variations': [{'variables': [],
#         'id': '16905960016',
#         'key': '16905960016',
#         'featureEnabled': False}],
#       'id': '16907470013',
#       'key': '16907470013',
#       'layerId': '16874821722',
#       'trafficAllocation': [],
#       'forcedVariations': {}}],
#     'id': '16874821722'},
#    {'experiments': [{'status': 'Not started',
#       'audienceIds': [],
#       'variations': [{'variables': [],
#         'id': '16917663475',
#         'key': '16917663475',
#         'featureEnabled': False}],
#       'id': '16911614747',
#       'key': '16911614747',
#       'layerId': '16884838662',
#       'trafficAllocation': [],
#       'forcedVariations': {}}],
#     'id': '16884838662'},
#    {'experiments': [{'status': 'Not started',
#       'audienceIds': [],
#       'variations': [{'variables': [],
#         'id': '16888890011',
#         'key': '16888890011',
#         'featureEnabled': False}],
#       'id': '16893273346',
#       'key': '16893273346',
#       'layerId': '16915500003',
#       'trafficAllocation': [],
#       'forcedVariations': {}}],
#     'id': '16915500003'},
#    {'experiments': [{'status': 'Not started',
#       'audienceIds': [],
#       'variations': [{'variables': [],
#         'id': '17508170158',
#         'key': '17508170158',
#         'featureEnabled': False}],
#       'id': '17504740750',
#       'key': '17504740750',
#       'layerId': '17529421541',
#       'trafficAllocation': [],
#       'forcedVariations': {}}],
#     'id': '17529421541'},
#    {'experiments': [{'status': 'Not started',
#       'audienceIds': [],
#       'variations': [{'variables': [],
#         'id': '17603320427',
#         'key': '17603320427',
#         'featureEnabled': False}],
#       'id': '17601340118',
#       'key': '17601340118',
#       'layerId': '17578650119',
#       'trafficAllocation': [],
#       'forcedVariations': {}}],
#     'id': '17578650119'},
#    {'experiments': [{'status': 'Not started',
#       'audienceIds': [],
#       'variations': [{'variables': [],
#         'id': '18128720030',
#         'key': '18128720030',
#         'featureEnabled': False}],
#       'id': '18136490023',
#       'key': '18136490023',
#       'layerId': '18124650838',
#       'trafficAllocation': [],
#       'forcedVariations': {}}],
#     'id': '18124650838'},
#    {'experiments': [{'status': 'Not started',
#       'audienceIds': [],
#       'variations': [{'variables': [],
#         'id': '18823661379',
#         'key': '18823661379',
#         'featureEnabled': False}],
#       'id': '18802794087',
#       'key': '18802794087',
#       'layerId': '18794122735',
#       'trafficAllocation': [],
#       'forcedVariations': {}}],
#     'id': '18794122735'},
#    {'experiments': [{'status': 'Running',
#       'audienceConditions': ['or', '18270960045'],
#       'audienceIds': ['18270960045'],
#       'variations': [{'variables': [],
#         'id': '18937544106',
#         'key': '18937544106',
#         'featureEnabled': True}],
#       'id': '18939563602',
#       'key': '18939563602',
#       'layerId': '18974032440',
#       'trafficAllocation': [{'entityId': '18937544106', 'endOfRange': 10000}],
#       'forcedVariations': {}}],
#     'id': '18974032440'},
#    {'experiments': [{'status': 'Not started',
#       'audienceIds': [],
#       'variations': [{'variables': [],
#         'id': '18983303919',
#         'key': '18983303919',
#         'featureEnabled': False}],
#       'id': '18970442311',
#       'key': '18970442311',
#       'layerId': '18983601713',
#       'trafficAllocation': [],
#       'forcedVariations': {}}],
#     'id': '18983601713'}],
#   'typedAudiences': [],
#   'anonymizeIP': True,
#   'projectId': '15265681341',
#   'variables': [],
#   'featureFlags': [{'experimentIds': [],
#     'rolloutId': '15409120907',
#     'variables': [],
#     'id': '15387770290',
#     'key': 'test01_feature_testing'},
#    {'experimentIds': [],
#     'rolloutId': '15842440850',
#     'variables': [],
#     'id': '15846761440',
#     'key': 'campaign_page_create_comment'},
#    {'experimentIds': [],
#     'rolloutId': '16506650013',
#     'variables': [],
#     'id': '16517370046',
#     'key': 'optimizely_x_feature'},
#    {'experimentIds': [],
#     'rolloutId': '16732750156',
#     'variables': [],
#     'id': '16728730318',
#     'key': 'campagin_page_state_label'},
#    {'experimentIds': [],
#     'rolloutId': '16753900914',
#     'variables': [],
#     'id': '16779180626',
#     'key': 'campaign_state_label'},
#    {'experimentIds': [],
#     'rolloutId': '16884838662',
#     'variables': [],
#     'id': '16896817586',
#     'key': 'campaign_top_donations_button'},
#    {'experimentIds': [],
#     'rolloutId': '16915500003',
#     'variables': [],
#     'id': '16900260021',
#     'key': 'campaign_state_label_trending'},
#    {'experimentIds': [],
#     'rolloutId': '16874821722',
#     'variables': [],
#     'id': '16902270012',
#     'key': 'campaign_state_label_new'},
#    {'experimentIds': [],
#     'rolloutId': '17529421541',
#     'variables': [],
#     'id': '17523651042',
#     'key': 'campaign_page_poster_share'},
#    {'experimentIds': [],
#     'rolloutId': '17578650119',
#     'variables': [],
#     'id': '17599790185',
#     'key': 'uc_recaptcha_fe'},
#    {'experimentIds': [],
#     'rolloutId': '18124650838',
#     'variables': [],
#     'id': '18140250710',
#     'key': 'campaign_guidance_drawer_donors'},
#    {'experimentIds': [],
#     'rolloutId': '18794122735',
#     'variables': [],
#     'id': '18800044174',
#     'key': 'updates_modal'},
#    {'experimentIds': [],
#     'rolloutId': '18974032440',
#     'variables': [],
#     'id': '18924213992',
#     'key': 'disable_apple_pay_for_certain_campaigns'},
#    {'experimentIds': [],
#     'rolloutId': '18983601713',
#     'variables': [],
#     'id': '18983572068',
#     'key': 'cp_guidance_vote'}],
#   'experiments': [{'status': 'Running',
#     'audienceConditions': ['or', '18270960045'],
#     'audienceIds': ['18270960045'],
#     'variations': [{'variables': [], 'id': '17949050755', 'key': 'control'},
#      {'variables': [], 'id': '17936420085', 'key': 'variant'}],
#     'id': '17866783721',
#     'key': 'uc_apple_pay',
#     'layerId': '17924760076',
#     'trafficAllocation': [{'entityId': '17936420085', 'endOfRange': 5000},
#      {'entityId': '17936420085', 'endOfRange': 10000}],
#     'forcedVariations': {}},
#    {'status': 'Running',
#     'audienceIds': [],
#     'variations': [{'variables': [], 'id': '18176770510', 'key': 'control'},
#      {'variables': [], 'id': '18190020610', 'key': 'variant'}],
#     'id': '18201262145',
#     'key': 'braintree_adyen',
#     'layerId': '18183951100',
#     'trafficAllocation': [{'entityId': '18190020610', 'endOfRange': 250},
#      {'entityId': '18190020610', 'endOfRange': 2500},
#      {'entityId': '18190020610', 'endOfRange': 4750},
#      {'entityId': '18190020610', 'endOfRange': 5000},
#      {'entityId': '18190020610', 'endOfRange': 5250},
#      {'entityId': '18190020610', 'endOfRange': 7500},
#      {'entityId': '18190020610', 'endOfRange': 10000}],
#     'forcedVariations': {'control': 'control', 'variant': 'variant'}},
#    {'status': 'Running',
#     'audienceIds': [],
#     'variations': [{'variables': [], 'id': '18238815855', 'key': 'control'},
#      {'variables': [], 'id': '18271545219', 'key': 'variant'}],
#     'id': '18273047686',
#     'key': 'secure-donation-icon',
#     'layerId': '18307313875',
#     'trafficAllocation': [{'entityId': '18271545219', 'endOfRange': 500},
#      {'entityId': '18271545219', 'endOfRange': 900},
#      {'entityId': '18271545219', 'endOfRange': 1400},
#      {'entityId': '18271545219', 'endOfRange': 1900},
#      {'entityId': '18271545219', 'endOfRange': 5000},
#      {'entityId': '18271545219', 'endOfRange': 5100},
#      {'entityId': '18271545219', 'endOfRange': 6000},
#      {'entityId': '18271545219', 'endOfRange': 10000}],
#     'forcedVariations': {}},
#    {'status': 'Running',
#     'audienceIds': [],
#     'variations': [{'variables': [], 'id': '18377650925', 'key': 'control'},
#      {'variables': [], 'id': '18365841011', 'key': 'variant'}],
#     'id': '18374492045',
#     'key': 'uc_security_campaign_summary',
#     'layerId': '18387080490',
#     'trafficAllocation': [{'entityId': '18365841011', 'endOfRange': 100},
#      {'entityId': '18365841011', 'endOfRange': 5000},
#      {'entityId': '18365841011', 'endOfRange': 10000}],
#     'forcedVariations': {'YL-152-variant': 'variant',
#      'YL-152-control': 'control'}},
#    {'status': 'Running',
#     'audienceIds': [],
#     'variations': [{'variables': [], 'id': '18933983573', 'key': 'control'},
#      {'variables': [], 'id': '18949042608', 'key': 'variant'}],
#     'id': '18932123279',
#     'key': 'uc_gfm_guarantee',
#     'layerId': '18975760284',
#     'trafficAllocation': [{'entityId': '18949042608', 'endOfRange': 1500},
#      {'entityId': '18949042608', 'endOfRange': 5000},
#      {'entityId': '18949042608', 'endOfRange': 6500},
#      {'entityId': '18949042608', 'endOfRange': 10000}],
#     'forcedVariations': {'YL-533-control': 'control',
#      'YL-533-variant': 'variant'}},
#    {'status': 'Running',
#     'audienceIds': [],
#     'variations': [{'variables': [], 'id': '18987771438', 'key': 'control'},
#      {'variables': [], 'id': '18989820868', 'key': 'variant'}],
#     'id': '19021610033',
#     'key': 'uc_stripe_google_apple_pay',
#     'layerId': '18968100805',
#     'trafficAllocation': [{'entityId': '18989820868', 'endOfRange': 500},
#      {'entityId': '18989820868', 'endOfRange': 1000},
#      {'entityId': '18989820868', 'endOfRange': 5000},
#      {'entityId': '18989820868', 'endOfRange': 10000}],
#     'forcedVariations': {'YL-38-control': 'control',
#      'YL-38-variant': 'variant',
#      'apple-variant': 'variant'}},
#    {'status': 'Running',
#     'audienceIds': [],
#     'variations': [{'variables': [],
#       'id': '19573954830',
#       'key': 'variantDrawer'},
#      {'variables': [], 'id': '19603493177', 'key': 'control'}],
#     'id': '19687101138',
#     'key': 'cp_team_drawer',
#     'layerId': '19601564554',
#     'trafficAllocation': [{'entityId': '19573954830', 'endOfRange': 5000},
#      {'entityId': '19603493177', 'endOfRange': 10000}],
#     'forcedVariations': {}},
#    {'status': 'Running',
#     'audienceIds': [],
#     'variations': [{'variables': [], 'id': '19736128489', 'key': 'control'},
#      {'variables': [], 'id': '19886440255', 'key': 'newSearch'}],
#     'id': '19910950511',
#     'key': 'cp_srp_experiment',
#     'layerId': '19756996815',
#     'trafficAllocation': [{'entityId': '19886440255', 'endOfRange': 5000},
#      {'entityId': '19736128489', 'endOfRange': 9000},
#      {'entityId': '19886440255', 'endOfRange': 10000}],
#     'forcedVariations': {'00-78ecfecb969f476cb2cc8fbf6953a5cb-f1f17934': 'newSearch',
#      '00-fefd4cf1a5394faaafd1949548486e88-b1b23d4f': 'newSearch',
#      '0ec3607b-eb55-4e93-9fe7-3e6025c76079': 'newSearch',
#      '00-c9ba2b410b004f418ef69b9bcb4c0cbb-8ea5b9ea': 'newSearch'}}],
#   'audiences': [{'id': '18270960045',
#     'conditions': '["and", ["or", ["not", ["or", {"match": "exact", "name": "fundUrl", "type": "custom_attribute", "value": "apple-time-test"}]]]]',
#     'name': 'Apple Pay Exclusions'},
#    {'conditions': '["or", {"match": "exact", "name": "$opt_dummy_attribute", "type": "custom_attribute", "value": "$opt_dummy_value"}]',
#     'id': '$opt_dummy_audience',
#     'name': 'Optimizely-Generated Audience for Backwards Compatibility'}],
#   'groups': [],
#   'attributes': [{'id': '15560710532', 'key': 'exp1'},
#    {'id': '15595650558', 'key': 'person_id'},
#    {'id': '16828570639', 'key': 'fundName'},
#    {'id': '16840181363', 'key': 'elementId'},
#    {'id': '16842171085', 'key': 'fundId'},
#    {'id': '16852903462', 'key': 'os'},
#    {'id': '16859981585', 'key': 'userId'},
#    {'id': '16860621018', 'key': 'device'},
#    {'id': '16861980693', 'key': 'viewId'},
#    {'id': '16865190855', 'key': 'fundUrl'},
#    {'id': '16869544615', 'key': 'browser'},
#    {'id': '17275644664', 'key': 'locale'},
#    {'id': '17289545132', 'key': 'personId'}],
#   'botFiltering': False,
#   'accountId': '14721270268',
#   'events': [{'experimentIds': [], 'id': '15559150355', 'key': 'test_event_1'},
#    {'experimentIds': ['17866783721',
#      '18201262145',
#      '18273047686',
#      '18374492045',
#      '18932123279',
#      '19021610033'],
#     'id': '15708130705',
#     'key': 'donation_complete'},
#    {'experimentIds': [],
#     'id': '15836640020',
#     'key': 'p41_sidebar_donate_button_click'},
#    {'experimentIds': [], 'id': '15838070586', 'key': 'customize_complete'},
#    {'experimentIds': [], 'id': '15838400177', 'key': 'donate_main_cta_click'},
#    {'experimentIds': [],
#     'id': '15850240277',
#     'key': 'p41_sidebar_share_button_click'},
#    {'experimentIds': [], 'id': '15859880655', 'key': 'share_main_cta_click'},
#    {'experimentIds': [],
#     'id': '16722610784',
#     'key': 'campaign_page.click.lb_share.btn_share_whatsapp'},
#    {'experimentIds': [],
#     'id': '16724870654',
#     'key': 'campaign_page.click.pg_donate_index.btn_nav_share'},
#    {'experimentIds': [],
#     'id': '16734450607',
#     'key': 'campaign_page.click.pg_donate_index.btn_share'},
#    {'experimentIds': [],
#     'id': '16746290110',
#     'key': 'campaign_page.click.lb_share.btn_share_facebook'},
#    {'experimentIds': [],
#     'id': '16747290559',
#     'key': 'campaign_page.click.lb_share.btn_share_twitter'},
#    {'experimentIds': [],
#     'id': '16747310489',
#     'key': 'campaign_page.click.pg_donate_index.btn_donate'},
#    {'experimentIds': [],
#     'id': '16750990447',
#     'key': 'campaign_page.click.lb_share.input_share_copy_link'},
#    {'experimentIds': [],
#     'id': '16751210584',
#     'key': 'campaign_page.click.lb_share.btn_share_email'},
#    {'experimentIds': [],
#     'id': '16751460406',
#     'key': 'campaign_page.click.pg_donate_index.btn_donate_sticky'},
#    {'experimentIds': [],
#     'id': '16753500101',
#     'key': 'campaign_page.click.lb_share.btn_share_copy_link'},
#    {'experimentIds': ['19910950511'],
#     'id': '16755540127',
#     'key': 'campaign_page.view.pg_donate_index'},
#    {'experimentIds': [],
#     'id': '16771050039',
#     'key': 'campaign_page.click.pg_donate_index.btn_donate_moredonations'},
#    {'experimentIds': [],
#     'id': '16836862870',
#     'key': 'campaign_page.click.pg_donate_index.share_button_clicks'},
#    {'experimentIds': [],
#     'id': '16848361312',
#     'key': 'campaign_page.click.pg_donate_index.btn_nav_donate'},
#    {'experimentIds': [],
#     'id': '16850345798',
#     'key': 'campaign_page.click.pg_donate_index.share_sheet_clicks'},
#    {'experimentIds': [],
#     'id': '16852240843',
#     'key': 'campaign_page.click.pg_donate_index.donate_button_clicks'},
#    {'experimentIds': [],
#     'id': '16863820916',
#     'key': 'campaign_page.click.lb_share.btn_share_fbmessenger'},
#    {'experimentIds': [],
#     'id': '16867230775',
#     'key': 'campaign_page.click.lb_share.btn_share_sms'},
#    {'experimentIds': [],
#     'id': '17010892988',
#     'key': 'campaign_page.click.lb_donation_list.btn_donations_donate'},
#    {'experimentIds': [],
#     'id': '17016121376',
#     'key': 'campaign_page.click.lb_donation_top.btn_donations_donate'},
#    {'experimentIds': [],
#     'id': '17018093010',
#     'key': 'campaign_page.click.lb_donation_list.btn_exp_donate'},
#    {'experimentIds': [],
#     'id': '17021741277',
#     'key': 'campaign_page.click.lb_share.btn_share_copy_link_tip'},
#    {'experimentIds': [],
#     'id': '17033612008',
#     'key': 'campaign_page.click.pg_donate_index.btn_exp_share'},
#    {'experimentIds': [],
#     'id': '17041041427',
#     'key': 'campaign_page.click.pg_donate_index.btn_exp_donate'},
#    {'experimentIds': [],
#     'id': '17065921352',
#     'key': 'post_donate.view.lb_postdonate_comment'},
#    {'experimentIds': ['19687101138', '19910950511'],
#     'id': '17117930134',
#     'key': 'post_donate.view.lb_postdonate_share'},
#    {'experimentIds': [],
#     'id': '17194210874',
#     'key': 'click.pg_donate_index.btn_navmenu_donate'},
#    {'experimentIds': [],
#     'id': '17254341635',
#     'key': 'campaign_create.click.pg_w_calender-reminder.btn_ss_add_ical'},
#    {'experimentIds': [],
#     'id': '17256472517',
#     'key': 'campaign_create.click.pg_w_share-sheet1.btn_ss_more'},
#    {'experimentIds': [],
#     'id': '17258403432',
#     'key': 'campaign_create.click.pg_w_share-sheet1.btn_embed'},
#    {'experimentIds': [],
#     'id': '17260392845',
#     'key': 'campaign_create.click.pg_w_calender-reminder.btn_ss_add_gcal'},
#    {'experimentIds': [],
#     'id': '17260503228',
#     'key': 'campaign_create.click.pg_w_share-sheet1.btn_ss_whatsapp'},
#    {'experimentIds': [],
#     'id': '17260725434',
#     'key': 'campaign_page.click.lb_share.btn_share_moreshares'},
#    {'experimentIds': [],
#     'id': '17262624345',
#     'key': 'campaign_create.view.pg_w_share-sheet1'},
#    {'experimentIds': [],
#     'id': '17263883058',
#     'key': 'campaign_create.click.pg_w_calender-reminder.btn_back'},
#    {'experimentIds': [],
#     'id': '17264403542',
#     'key': 'campaign_create.click.pg_w_share_message2.btn_manage'},
#    {'experimentIds': [],
#     'id': '17266521779',
#     'key': 'campaign_create.click.pg_w_share-sheet1.btn_ss_text_client'},
#    {'experimentIds': [],
#     'id': '17271552441',
#     'key': 'campaign_create.click.pg_w_share-sheet1.btn_nav_gfm_logo'},
#    {'experimentIds': [],
#     'id': '17272040825',
#     'key': 'campaign_create.click.pg_w_share-sheet1.btn_print_sign'},
#    {'experimentIds': [],
#     'id': '17272055461',
#     'key': 'campaign_create.click.pg_w_share-sheet1.input_ss_copy_link'},
#    {'experimentIds': [],
#     'id': '17272074011',
#     'key': 'campaign_create.click.pg_w_share-sheet1.btn_ss_twitter_client'},
#    {'experimentIds': [],
#     'id': '17273753737',
#     'key': 'campaign_create.click.pg_w_share-sheet1.btn_ss_facebook_post'},
#    {'experimentIds': [],
#     'id': '17275393286',
#     'key': 'campaign_create.view.pg_w_share_message3-5'},
#    {'experimentIds': [],
#     'id': '17277854395',
#     'key': 'campaign_create.view.pg_w_share_message2'},
#    {'experimentIds': [],
#     'id': '17279409319',
#     'key': 'campaign_create.click.pg_w_calender-reminder.btn_nav_gfm_logo'},
#    {'experimentIds': [],
#     'id': '17279561778',
#     'key': 'campaign_create.click.pg_w_share-sheet1.btn_ss_messenger'},
#    {'experimentIds': [],
#     'id': '17279698624',
#     'key': 'campaign_page.click.pg_donate_index.btn_story_share'},
#    {'experimentIds': [],
#     'id': '17279793149',
#     'key': 'campaign_create.view.pg_w_calender-reminder'},
#    {'experimentIds': [],
#     'id': '17283052762',
#     'key': 'campaign_create.click.pg_w_calender-reminder.btn_manage'},
#    {'experimentIds': [],
#     'id': '17283196007',
#     'key': 'campaign_create.click.pg_w_share_message2.btn_nav_gfm_logo'},
#    {'experimentIds': [],
#     'id': '17287504620',
#     'key': 'campaign_create.view.pg_w_share-sheet3-5'},
#    {'experimentIds': [],
#     'id': '17287528318',
#     'key': 'campaign_create.click.pg_w_share-sheet1.btn_ss_copylink'},
#    {'experimentIds': [],
#     'id': '17291083266',
#     'key': 'campaign_create.click.pg_w_share-sheet1.btn_next'},
#    {'experimentIds': [],
#     'id': '17298994388',
#     'key': 'campaign_page.click.lb_donation_list.btn_donations_message'},
#    {'experimentIds': [],
#     'id': '17357691674',
#     'key': 'campaign_create.click.pg_w_share_message2.btn_skip'},
#    {'experimentIds': [],
#     'id': '17361961023',
#     'key': 'campaign_page.click.pg_donate_index.btn_story_donate'},
#    {'experimentIds': [],
#     'id': '17376630324',
#     'key': 'campaign_create.click.pg_w_share-sheet1.btn_ss_email_client'},
#    {'experimentIds': [],
#     'id': '17388060791',
#     'key': 'campaign_page.click.pg_donate_index.btn_share_sticky'},
#    {'experimentIds': [],
#     'id': '17409230386',
#     'key': 'campaign_create.click.pg_w_share_message2.btn_back'},
#    {'experimentIds': [],
#     'id': '17420601969',
#     'key': 'campaign_page.click.lb_share.btn_share_print'},
#    {'experimentIds': [],
#     'id': '17735490348',
#     'key': 'post_donate.click.lb_postdonate_share.share_button_clicks'},
#    {'experimentIds': [],
#     'id': '17740061031',
#     'key': 'post_donate.click.lb_postdonate_comment.btn_comment'},
#    {'experimentIds': [],
#     'id': '18182881630',
#     'key': 'campaign_page.click.lb_postdonate_share.share_button_clicks'},
#    {'experimentIds': [],
#     'id': '18197951655',
#     'key': 'post_donate.click.lb_postdonate_share.share_clicks'},
#    {'experimentIds': [],
#     'id': '18199381205',
#     'key': 'click.pg_donate_index.pg_guidance_card_link'},
#    {'experimentIds': [],
#     'id': '18201231289',
#     'key': 'campaign_page.click.pg_donate_index.share_clicks'},
#    {'experimentIds': [],
#     'id': '18201532087',
#     'key': 'click.pg_donate_index.pg_guidance_card_facebook'},
#    {'experimentIds': ['19687101138'],
#     'id': '18213170197',
#     'key': 'capapodo.click.shares'},
#    {'experimentIds': [],
#     'id': '18269212706',
#     'key': 'post_donate.click.lb_postdonate_share.input_share_copy_link'},
#    {'experimentIds': [],
#     'id': '18269341618',
#     'key': 'post_donate.click.lb_postdonate_share.btn_share_copy_link'},
#    {'experimentIds': ['18374492045'],
#     'id': '18813682278',
#     'key': 'effective_rate_tip_amounts'},
#    {'experimentIds': [],
#     'id': '19920433011',
#     'key': 'campaign_create.view.pg_campaign_details'},
#    {'experimentIds': [],
#     'id': '19928081621',
#     'key': 'campaign_create.view.pg_campaign_kyc'},
#    {'experimentIds': [],
#     'id': '19934922490',
#     'key': 'campaign_create.view.pg_campaign_goal'},
#    {'experimentIds': [],
#     'id': '19936642765',
#     'key': 'campaign_create.view.pg_campaign_media'},
#    {'experimentIds': [],
#     'id': '19942070927',
#     'key': 'campaign_create.view.pg_campaign_doors'},
#    {'experimentIds': [],
#     'id': '19943423135',
#     'key': 'campaign_create.view.pg_campaign_ready'},
#    {'experimentIds': [],
#     'id': '19943472944',
#     'key': 'campaign_create.view.pg_campaign_ppgfagreement'},
#    {'experimentIds': [],
#     'id': '19949363090',
#     'key': 'campaign_create.click.pg_campaign_media.btn_next_campaign_media'},
#    {'experimentIds': [],
#     'id': '19949392500',
#     'key': 'campaign_create.view.pg_charity_campaign_details'},
#    {'experimentIds': [],
#     'id': '19954943789',
#     'key': 'campaign_create.view.pg_campaign_story'}],
#   'revision': '2269'},
#  'template': {},
#  'ui': {'alertContent': {'message': '', 'type': 'error'},
#   'infoContent': {'message': ''}},
#  'urlshortner': {'shortenedShareUtmUrls': {'SMS_ANDROID_SHARESHEET': {'CAMPAIGN_PAGE': '',
#     'POSTCREATE_CAMPAIGN': '',
#     'POSTDONATE_MODAL': ''},
#    'EMAIL_ANDROID_SHARESHEET': {'CAMPAIGN_PAGE': '',
#     'POSTCREATE_CAMPAIGN': '',
#     'POSTDONATE_MODAL': ''},
#    'PRINT_POSTER': {'CAMPAIGN_PAGE': '', 'POSTDONATE_MODAL': ''},
#    'COPY_LINK_ALL': {'CAMPAIGN_PAGE': '', 'POSTDONATE_MODAL': ''}}}}
