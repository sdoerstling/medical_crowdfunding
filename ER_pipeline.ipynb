# %% [markdown]
# ### Import packages

# %%
import os
import json
import pandas as pd
import numpy as np
import sqlite3
import json
import copy
import re
import operator
import math

# %% [markdown]
# ### Import CCSR data

# %%
# ccsr = pd.read_excel("disease_hierarchy/CCSR_for_ICD10/CCSR.xlsx", sheet_name='DX_to_CCSR_Mapping', skiprows=1)

# %%
ccsr = pd.read_csv("disease_hierarchy/CCSR_for_ICD10/DXCCSR_v2021-1.CSV")

# %%
ccsr.columns = [x.replace("'",'') for x in ccsr.columns]

# %%
ccsr = ccsr[ccsr.columns[:6,].values]

# %%
for n in [0,2,4]:
    ccsr.iloc[:,n] = [x.replace("'",'') for x in ccsr.iloc[:,n].to_list()]

# %%
ccsr.head()
# Out:
#   ICD-10-CM CODE                         ICD-10-CM CODE DESCRIPTION  \
# 0           A000  Cholera due to Vibrio cholerae 01, biovar chol...
# 1           A001    Cholera due to Vibrio cholerae 01, biovar eltor
# 2           A009                               Cholera, unspecified
# 3          A0100                         Typhoid fever, unspecified
# 4          A0101                                 Typhoid meningitis
#
#   Default CCSR CATEGORY IP Default CCSR CATEGORY DESCRIPTION IP  \
# 0                   DIG001                 Intestinal infection
# 1                   DIG001                 Intestinal infection
# 2                   DIG001                 Intestinal infection
# 3                   DIG001                 Intestinal infection
# 4                   NVS001                           Meningitis
#
#   Default CCSR CATEGORY OP Default CCSR CATEGORY DESCRIPTION OP
# 0                   DIG001                 Intestinal infection
# 1                   DIG001                 Intestinal infection
# 2                   DIG001                 Intestinal infection
# 3                   DIG001                 Intestinal infection
# 4                   NVS001                           Meningitis

# %%
dh = pd.read_excel("disease_hierarchy/disease_hierarchy.xlsx")

# %%
merged = ccsr.merge(dh, how='left', left_on = 'Default CCSR CATEGORY DESCRIPTION IP', right_on ='Level 3')

# %%
#merged.to_csv("ccsr_manual_hierarchy.csv", index=False)

# %% [markdown]
# ##### hierarchy was manually revised

# %%
ccsr = pd.read_csv("disease_hierarchy/ccsr_manual_hierarchy_revised.csv")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (6,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ccsr['Level 2'].unique()
# Out:
# array(['Coronary artery disease', 'Heart failure',
#        'Other cardiovascular disorders', 'Stroke', 'No specific choices',
#        'Diabetes', 'Other endocrine disorders', 'Liver diseases',
#        'Other gastrointestinal disorders', 'Chronic kidney disease',
#        'Other genitourinary disorders', 'HIV/AIDS', 'Other infections',
#        'Other injuries and external causes', 'Other mental disorders',
#        'Substance use disorders', 'Other musculoskeletal disorders',
#        'Rheumatologic disorders', 'Brain cancer', 'Breast cancer',
#        'Colorectal cancer', 'Other neoplasms', 'Hematologic malignancies',
#        'Prostate cancer', 'Lung cancer', 'Multiple sclerosis',
#        'Neurodegenerative diseases', 'Other neurologic disorders',
#        'Neurodenerative diseases', 'COPD', 'Other respiratory disorders',
#        nan], dtype=object)

# %%
ccsr['Level 1'].unique()
# Out:
# array(['Cardiovascular diseases',
#        'Chromosomal, congenital, and perinatal disorders',
#        'Endocrine diseases', 'Gastrointestinal diseases',
#        'Genitourinary disorders', 'Infections',
#        'Injuries and external causes',
#        'Mental, behavioral, and substance use disorders',
#        'Musculoskeletal diseases', 'Neoplasms', 'Nervous system diseases',
#        'Nonspecific', 'Other noncommunicable diseases',
#        'Pregnancy and childbirth', 'Respiratory diseases', nan],
#       dtype=object)

# %%
ccsr.columns
# Out:
# Index(['ICD-10-CM CODE', 'ICD-10-CM CODE DESCRIPTION',
#        'Default CCSR CATEGORY IP', 'Default CCSR CATEGORY DESCRIPTION IP',
#        'Default CCSR CATEGORY OP', 'Default CCSR CATEGORY DESCRIPTION OP',
#        'Level 3', 'Level 2', 'Level 1'],
#       dtype='object')

# %%
ccsr = pd.read_excel('Manual_Review/disease_hierarchy_11.30.2020.xlsx')

# %% [markdown]
# ### Import SNOMED to ICD data

# %%
conn = sqlite3.connect("SNOMED_to_ICD10.db")
snomed = pd.read_sql_query("SELECT * FROM map_tb", conn)
conn.close()

# %% [markdown]
# ### Import ATHENA data

# %%
conn = sqlite3.connect("ATHENA.db")
athena = pd.read_sql_query("SELECT * FROM concept_tb WHERE domain_id = 'Condition'", conn)
conn.close()

# %% [markdown]
# ### Import NER output

# %%
with open('Manual_Review/round 2/ner_disease_ner_clinical_icd10.json') as f:
     r_icd = json.load(f)

# %%
with open('Manual_Review/round 2/ner_disease_ner_clinical_snomed.json') as f:
     r_snomed = json.load(f)

# %%
with open('Manual_Review/round 2/ner_disease_ner_healthcare_athena.json') as f:
     r_athena = json.load(f)

# %% [markdown]
# ### Define Functions

# %%
def GetTopICD(lofd):
    results = []
    for d in lofd:
        dic = copy.deepcopy(d)
        for n in range(0, len(d['entity'])):
            dic['entity'][n]['icd_code'] = dic['entity'][n]['all_k_results'].split(':::')[0]
        results.append(dic)
    return results

# %%
def GetTopSnomed(lofd):
    results = []
    for d in lofd:
        dic = copy.deepcopy(d)
        for n in range(0, len(d['entity'])):
            dic['entity'][n]['concept_code'] = dic['entity'][n]['all_k_results'].split(':::')[0]
        results.append(dic)
    return results

# %%
def SnomedToICD(df):
    asdf = copy.deepcopy(df)
    asdf['concept_code'] = asdf['concept_code'].astype(int)
    merge = asdf.merge(snomed, how='left', left_on='concept_code', right_on='referencedComponentId')
    # FIND WAY TO SELECT DEFAULT SNOMED
    merge = merge[merge['mapGroup'] == 1]
    merge['mapTarget'] = [x.replace('.','') if x != None else x for x in merge['mapTarget']]
    merge = merge.dropna(subset=['mapTarget'])
    return merge

# %%
def SnomedToCategoryScores(lofd, distance):
    results = []
    for d in lofd:
        dic = copy.deepcopy(d)
        df = pd.DataFrame(dic['entity'])
        df_sno_icd = SnomedToICD(df)
        df_sno_icd_ccsr = df_sno_icd.merge(ccsr, how='left', left_on='mapTarget', right_on='ICD-10-CM CODE')
        dic['merge'] = df_sno_icd_ccsr
        dic['scores_level_2'] = df_sno_icd_ccsr.groupby(['Level 2'])[distance].sum().to_dict()
        dic['scores_level_1'] = df_sno_icd_ccsr.groupby(['Level 1'])[distance].sum().to_dict()
        dic['level_2'] = max(dic['scores_level_2'].items(), key=operator.itemgetter(1))[0]
        dic['level_1'] = max(dic['scores_level_1'].items(), key=operator.itemgetter(1))[0]
        results.append(dic)
    return results

# %%
def MergeAthena(lofd):
    results = []
    for d in lofd:
        dic = copy.deepcopy(d)
        if len(dic['entity']) == 0:
            dic['merge'] = {}
            results.append(dic)
        else:
            df = pd.DataFrame(dic['entity'])
            df['all_k_results'] = df['all_k_results'].astype(int)
            merge = df.merge(athena, how='left', left_on='all_k_results', right_on='concept_id')
            dic['merge'] = merge.to_dict()
            results.append(dic)
    return results

# %%
def AthenaToCategoryScores(lofd, distance):
    results = []
    for d in lofd:
        dic = copy.deepcopy(d)
        if len(dic['merge']) == 0:
            dic['scores_level_2'] = np.nan
            dic['scores_level_1'] = np.nan
            dic['level_2'] = np.nan
            dic['level_1'] = np.nan
            results.append(dic)
        else:
            df = pd.DataFrame(dic['merge'])
            df = df.dropna(subset=['concept_code'])
            if df['vocabulary_id'].str.contains('ICD10CM').any():
                if df['vocabulary_id'].str.contains('SNOMED').any():

                    #ICD10 susbet
                    df_icd = df[df['vocabulary_id'] == 'ICD10CM']
                    df_icd_ccsr = df_icd.merge(ccsr, how='left', left_on='concept_code', right_on='ICD-10-CM CODE')

                    #SNOMED subset
                    df_sno = df[df['vocabulary_id'] == 'SNOMED']
                    df_sno_icd = SnomedToICD(df_sno)
                    df_sno_icd_ccsr = df_sno_icd.merge(ccsr, how='left', left_on='mapTarget', right_on='ICD-10-CM CODE')

                    #Row-bind subsets
                    df_sno_icd_ccsr = df_sno_icd_ccsr[['Level 3','Level 2','Level 1','inv_distance','exp_distance']]
                    df_icd_ccsr = df_icd_ccsr[['Level 3','Level 2','Level 1','inv_distance','exp_distance']]
                    rbind = pd.concat([df_sno_icd_ccsr,df_icd_ccsr])
                    dic['scores_level_2'] = rbind.groupby(['Level 2'])[distance].sum().to_dict()
                    dic['scores_level_1'] = rbind.groupby(['Level 1'])[distance].sum().to_dict()
                    if len(dic['scores_level_2']) == 0:
                        dic['level_2'] = np.nan
                    else:
                        dic['level_2'] = max(dic['scores_level_2'].items(), key=operator.itemgetter(1))[0]
                    if len(dic['scores_level_1']) == 0:
                        dic['level_1'] = np.nan
                    else:
                        dic['level_1'] = max(dic['scores_level_1'].items(), key=operator.itemgetter(1))[0]

                else:
                    df_icd_ccsr = df.merge(ccsr, how='left', left_on='concept_code', right_on='ICD-10-CM CODE')
                    dic['scores_level_2'] = df_icd_ccsr.groupby(['Level 2'])[distance].sum().to_dict()
                    dic['scores_level_1'] = df_icd_ccsr.groupby(['Level 1'])[distance].sum().to_dict()
                    if len(dic['scores_level_2']) == 0:
                        dic['level_2'] = np.nan
                    else:
                        dic['level_2'] = max(dic['scores_level_2'].items(), key=operator.itemgetter(1))[0]
                    if len(dic['scores_level_1']) == 0:
                        dic['level_1'] = np.nan
                    else:
                        dic['level_1'] = max(dic['scores_level_1'].items(), key=operator.itemgetter(1))[0]

            else:
                df_sno_icd = SnomedToICD(df)
                df_sno_icd_ccsr = df_sno_icd.merge(ccsr, how='left', left_on='mapTarget', right_on='ICD-10-CM CODE')
                dic['scores_level_2'] = df_sno_icd_ccsr.groupby(['Level 2'])[distance].sum().to_dict()
                dic['scores_level_1'] = df_sno_icd_ccsr.groupby(['Level 1'])[distance].sum().to_dict()
                if len(dic['scores_level_2']) == 0:
                    dic['level_2'] = np.nan
                else:
                    dic['level_2'] = max(dic['scores_level_2'].items(), key=operator.itemgetter(1))[0]
                if len(dic['scores_level_1']) == 0:
                    dic['level_1'] = np.nan
                else:
                    dic['level_1'] = max(dic['scores_level_1'].items(), key=operator.itemgetter(1))[0]



            results.append(dic)
    return results

# %%
def ScaleDistance(lofd):
    results = []
    for d in lofd:
        dic = copy.deepcopy(d)
        for  n in range(0, len(d['entity'])):
            dic['entity'][n]['inv_distance'] = [1/x if x > 0 else 100 for x in [float(dic['entity'][n]['distance'])]][0]
            dic['entity'][n]['exp_distance'] = [math.exp(-x) for x in [float(dic['entity'][n]['distance'])]][0]
        results.append(dic)
    return results

# %%
# def CalculateSentenceScore(lofd):
#     '''
#     calculates inverse of sentence position/total number of sentences
#     '''
#     results = []
#     for d in lofd:
#         dic = copy.deepcopy(d)
#         num_sent = dic['num_sentences']
#         for  n in range(0, len(d['entity'])):
#             #make sentence position 1-based
#             sent = int(dic['entity'][n]['sentence']) + 1
#             dic['entity'][n]['sent_score'] = 1/(sent/num_sent)
#         results.append(dic)
#     return results

# %%
def GetCategoryScoresICD(lofd, distance):
    results = []
    for d in lofd:
        dic = copy.deepcopy(d)
        if len(dic['entity']) == 0:
            dic['scores_level_2'] = np.nan
            dic['scores_level_1'] = np.nan
            dic['level_2'] = np.nan
            dic['level_1'] = np.nan
            results.append(dic)
        else:
            df = pd.DataFrame(dic['entity'])
            merge = df.merge(ccsr, how='left', left_on='icd_code', right_on='ICD-10-CM CODE')
            dic['merge'] = merge.to_dict()
            dic['scores_level_2'] = merge.groupby(['Level 2'])[distance].sum().to_dict()
            dic['scores_level_1'] = merge.groupby(['Level 1'])[distance].sum().to_dict()
            if len(dic['scores_level_2']) == 0:
                dic['level_2'] = np.nan
            else:
                dic['level_2'] = max(dic['scores_level_2'].items(), key=operator.itemgetter(1))[0]
            if len(dic['scores_level_1']) == 0:
                dic['level_1'] = np.nan
            else:
                dic['level_1'] = max(dic['scores_level_1'].items(), key=operator.itemgetter(1))[0]
            results.append(dic)
    return results

# %% [markdown]
# #### ICD pipeline

# %%
df = pd.DataFrame(r_icd)

# %%
import nltk
from nltk.corpus import stopwords
cachedStopWords = stopwords.words("english")
def RemoveStopwords(s):
    return ' '.join([word for word in s.split() if word not in cachedStopWords])

# %%
def GetNER(lofd):
    df = pd.DataFrame(lofd)
    r = []
    for chunk in df['ner_chunk']:
        if len(chunk) < 1:
            r.append([])
        else:
            l = []
            for res in chunk:
                l.append(RemoveStopwords(res['result'].lower()))
            r.append(l)
    return r

# %%
df['ner'] = GetNER(df)

# %%
df['ner'][19]
# Out:
# ['retinopathy prematurity',
#  'eye cancer right eye',
#  'retinoblastoma',
#  'cancer',
#  'progressive decrease',
#  'retinoblastoma',
#  'agradecería']

# %%
df['fund_description'][19]
# Out:
# ' ENGLISH    My name is Dahiana Clavijo and I was born with a condition called retinopathy of prematurity, because I was born five months of gestation. At nine years old, I was detected an eye cancer in the right eye called retinoblastoma, which causes my eye to be removed. A few months ago, when I went to an ophthalmologic review, I am informed that the cancer has returned but that my body blocked it by calcifying the back of my left eye and causing its progressive decrease; The doctor offers me an alternative to surgery, because it is quite expensive and I do not have the resources or social security to pay for it; The alternative is to buy two prostheses so that my eyes look the same size and color, thus increasing my self-confidence. I thank you in advance for the support you want to give me and although I know it is not easy, I hope you can donate. thank you very much for your attention.  ESPAÑOL  Mi nombre es Dahiana Clavijo y nací con una afección llamada retinopatía del prematuro, porque nací cinco meses de gestación. A los nueve años, me detectaron con un cáncer en mi ojo derecho llamado retinoblastoma, que hace que me extirpen el ojo. Hace unos meses, cuando fui a una revisión oftalmológica, me informaron que el cáncer había regresado pero que mi cuerpo lo bloqueó al calcificar la parte posterior de mi ojo izquierdo y causar su disminución progresiva; El médico me ofrece una alternativa a la cirugía, pero es bastante costosa y no tengo los recursos ni el seguro para pagarla; La alternativa es comprar dos prótesis para que mis ojos se vean del mismo tamaño y color, ya que Cómo les decía  el cancer en mis ojos continúa progresando y sus secuelas se vuelven más dolorosas cada día. y te pido que me ayudes. Agradecería. de todo corazón tu donación gracias por tu atención.'

# %%
df = pd.DataFrame(r)

# %%
df
# Out:
#                                                   url  \
# 0        https://www.gofundme.com/f/JosiahAnakinLopez
# 1        https://www.gofundme.com/f/Kayataskidsclinic
# 2   https://www.gofundme.com/f/lindsey-and-adam-di...
# 3   https://www.gofundme.com/f/ruths-skin-removal-...
# 4              https://www.gofundme.com/f/billbrownlv
# 5   https://www.gofundme.com/f/angel-sarah-forever...
# 6             https://www.gofundme.com/f/SavingTyisha
# 7                https://www.gofundme.com/f/xm4c4cq7q
# 8           https://www.gofundme.com/f/cheyennejensen
# 9               https://www.gofundme.com/f/22iq896m5c
# 10                https://www.gofundme.com/f/2bkkgaq4
# 11  https://www.gofundme.com/f/nmcs6-jacks-medical...
# 12                 https://www.gofundme.com/f/teamjoc
# 13  https://www.gofundme.com/f/coach-chucks-living...
# 14                 https://www.gofundme.com/f/5q5oals
# 15                https://www.gofundme.com/f/ytky34r8
# 16             https://www.gofundme.com/f/aLittleYoga
# 17  https://www.gofundme.com/f/mdr5e-medical-expen...
# 18                 https://www.gofundme.com/f/3s01f0o
# 19      https://www.gofundme.com/f/new-eye-prostheses
# 20              https://www.gofundme.com/f/tangopolly
# 21        https://www.gofundme.com/f/helpsarahbanning
# 22  https://www.gofundme.com/f/weregoingtofight-bo...
# 23                 https://www.gofundme.com/f/xqs55f7
# 24            https://www.gofundme.com/f/TruverFamily
# 25  https://www.gofundme.com/f/mariah-gibson-traum...
# 26                  https://www.gofundme.com/f/b925sc
# 27                https://www.gofundme.com/f/k9v7rvss
# 28                https://www.gofundme.com/f/2hp65afg
# 29  https://www.gofundme.com/f/5cv535-cancer-treat...
# 30                  https://www.gofundme.com/f/fzwoa8
# 31                https://www.gofundme.com/f/2phb83rg
# 32            https://www.gofundme.com/f/pawpawgaines
# 33          https://www.gofundme.com/f/aydens-miracle
# 34  https://www.gofundme.com/f/living-expensesmedi...
# 35  https://www.gofundme.com/f/quotlife-saving-sur...
# 36             https://www.gofundme.com/f/JustinWeber
# 37                  https://www.gofundme.com/f/lmagan
# 38                  https://www.gofundme.com/f/co1efs
# 39      https://www.gofundme.com/f/LauraLymeTreatment
# 40                  https://www.gofundme.com/f/m5mzoc
# 41               https://www.gofundme.com/f/Jacobseye
# 42          https://www.gofundme.com/f/jenniferwright
# 43  https://www.gofundme.com/f/new-partial-for-my-...
# 44  https://www.gofundme.com/f/wesley-needs-a-live...
#
#                                      fund_description  num_sentences  \
# 0   We will be having my sons open heart surgery i...              2
# 1   THE STORY: Welcome!  My name is Porkpa Tokpa  ...             49
# 2   Lindsey and Adam met in high school, supported...              9
# 3   ￼My name is Ruth I weighed 380lbs plus. I had ...             24
# 4   Most people celebrate the holidays by looking ...             37
# 5   Sarah was a bright and determined girl, seekin...              5
# 6   My beautiful sister, Tyisha Prescott, who was ...             37
# 7   "Your life can change in an instant." We've al...             20
# 8   There are so many people who love Cheyenne Hop...             19
# 9   Iam raising money to pay off my medical expens...              1
# 10  This is sweet Lily Grace Douglas who is the on...             21
# 11  We are raising money to help sweet Jack and hi...             77
# 12  “A hero is an ordinary individual who finds th...             74
# 13  This GoFundMe was created with the intention o...             24
# 14  Millie & Her Family Need Your Support!On June ...             23
# 15  I have been in a wheelchair for 8 months now, ...              7
# 16  Hey, Everyone!  My name is Katherine and yes, ...             52
# 17  On May 25th my cousin's 33 year old son, Jonat...             14
# 18  Hey guys my name is Marissa for those of you w...             20
# 19   ENGLISH    My name is Dahiana Clavijo and I w...             15
# 20  2013 respiratory failure caused by lung damage...              8
# 21  Hello!  On April 15th our dear friend Sarah wa...             12
# 22  I never imagined I'd have to write one of thes...             36
# 23  Jerry Borowski was an amazing Husband, brother...             28
# 24  SHORT VERSION : We took Doug’s [very small, ve...             45
# 25  Mariah Gibson was in a bad accident in forest ...              7
# 26  Brenda Ann was born on October 24, 1992. She w...             18
# 27  On January 1, 2016 my Uncle Andy had a medical...             34
# 28  To my fellow Cancer Haters: My friend Krista K...             19
# 29  You all know Cathy Eldred (Aldrich), a graduat...             30
# 30  About 3 weeks ago Madison went into the hospit...             18
# 31  Hello, I am Kenny Hall, a 55 year old who need...              8
# 32  Our sweet fun loving Daddy (Pawpaw) was diagno...             29
# 33  THE BACK STORY:   Ayden spent his first week o...             25
# 34  As Some of You May know already I Suffer from ...              1
# 35  "Life-Saving Surgery for Sahra Suber" I am mov...             29
# 36  Hello again! How amazing is it that the Weber'...              7
# 37  My name is Liezl Magan. I'm 32 years old and I...             70
# 38  Joey's illness has baffled the Doctors, nurses...             15
# 39  Help Aid Laura in Her Fight with Late Stage Ne...             24
# 40  My Baby " Cheska " a 1 year old girl  was diag...              5
# 41  This is my 15 month  old grandson Jacob. Think...              9
# 42  My sister-in-law's name is Jennifer Wright and...             12
# 43  The woman pictured is my beautiful wife. While...             13
# 44  Wesley is a 41-year-old man from PA who is in ...             15
#
#                                             ner_chunk  \
# 0                                                  []
# 1   [{'result': 'infections', 'sentence': 18}, {'r...
# 2   [{'result': 'acute neurological dysfunction', ...
# 3   [{'result': 'sleep apnea', 'sentence': 1}, {'r...
# 4   [{'result': 'the pressure on his brain', 'sent...
# 5   [{'result': 'Acute Lymphoblastic Leukemia', 's...
# 6   [{'result': 'Stage 4 Undifferentiated Cancer',...
# 7   [{'result': 'badly injured', 'sentence': 7}, {...
# 8   [{'result': 'AML Leukemia', 'sentence': 2}, {'...
# 9                                                  []
# 10  [{'result': 'infantile Scoliosis', 'sentence':...
# 11  [{'result': 'a persistent headache', 'sentence...
# 12  [{'result': 'overwhelming obstacles', 'sentenc...
# 13  [{'result': 'Amyotrophic Lateral Sclerosis', '...
# 14  [{'result': 'a severe headache', 'sentence': 0...
# 15                                                 []
# 16  [{'result': 'MDA', 'sentence': 2}, {'result': ...
# 17  [{'result': 'very badly burned', 'sentence': 0...
# 18  [{'result': 'a swollen arm', 'sentence': 2}, {...
# 19  [{'result': 'retinopathy of prematurity', 'sen...
# 20  [{'result': 'respiratory failure', 'sentence':...
# 21  [{'result': 'breathing problems', 'sentence': 1}]
# 22  [{'result': 'pain', 'sentence': 3}, {'result':...
# 23  [{'result': 'cancer', 'sentence': 1}, {'result...
# 24  [{'result': 'PAY DECREASE', 'sentence': 8}, {'...
# 25  [{'result': 'the biggest sweetheart', 'sentenc...
# 26  [{'result': 'Cystic Fibrosis', 'sentence': 4},...
# 27  [{'result': 'a mass on his Right Frontal Lobe'...
# 28  [{'result': 'Cancer', 'sentence': 0}, {'result...
# 29  [{'result': 'fixed', 'sentence': 1}, {'result'...
# 30  [{'result': 'complications', 'sentence': 0}, {...
# 31  [{'result': 'spinal cord damage', 'sentence': 1}]
# 32  [{'result': 'Esophageal cancer', 'sentence': 0...
# 33  [{'result': 'his severe scoliosis', 'sentence'...
# 34  [{'result': 'Neuropathy of the Feet', 'sentenc...
# 35  [{'result': 'weak', 'sentence': 8}, {'result':...
# 36                                                 []
# 37  [{'result': 'a weird sensation', 'sentence': 5...
# 38  [{'result': 'Joey's illness', 'sentence': 0}, ...
# 39  [{'result': 'Late Stage Neurological Lyme Dise...
# 40  [{'result': 'chronic liver disease', 'sentence...
# 41  [{'result': 'a lazy eye', 'sentence': 1}, {'re...
# 42  [{'result': 'stage 4 terminal cancer', 'senten...
# 43  [{'result': 'the panic of throwing', 'sentence...
# 44  [{'result': 'primary sclerosing cholangitis', ...
#
#                                                chunks  \
# 0                                                  []
# 1          [infections, fevers, clinic's septic tank]
# 2                    [acute neurological dysfunction]
# 3   [sleep apnea, borderline diabetic, it.The pain...
# 4   [pressure on brain, basically BORG, stroke, pr...
# 5                      [Acute Lymphoblastic Leukemia]
# 6   [Stage 4 Undifferentiated Cancer, mass between...
# 7                       [badly injured, unresponsive]
# 8                              [AML Leukemia, cancer]
# 9                                                  []
# 10  [infantile Scoliosis, recent growth spurt, ext...
# 11  [persistent headache, little slow, wobbly on f...
# 12  [overwhelming obstacles, incurable cancer, fir...
# 13  [Amyotrophic Lateral Sclerosis, ALS, permanent...
# 14        [severe headache, headache, brain aneurysm]
# 15                                                 []
# 16  [MDA, Duchenne Muscular Dystrophy, muscle wast...
# 17  [very badly burned, 2nd degree burns on face, ...
# 18   [swollen arm, blood clot near heart, blood clot]
# 19  [retinopathy of prematurity, eye cancer in rig...
# 20  [respiratory failure, lung damage, breast canc...
# 21                               [breathing problems]
# 22  [pain, some numbness, infection, infection, pa...
# 23  [cancer, wicked illness, illness, noticeable v...
# 24  [PAY DECREASE, then Doug's surgical injury, OU...
# 25                               [biggest sweetheart]
# 26  [Cystic Fibrosis, genetic disease, CF, fat-sol...
# 27  [mass on Right Frontal Lobe, cyst, cyst, life ...
# 28  [Cancer, cancer, endometrial cancer, aggressiv...
# 29  [fixed, Cancer, Animales Atenas, cervical canc...
# 30  [complications, infected kidney stone, infecti...
# 31                               [spinal cord damage]
# 32  [Esophageal cancer, Thoracotomy, esophageal re...
# 33  [severe scoliosis, many complications, adolesc...
# 34  [Neuropathy of Feet, Extremely Painful Conditi...
# 35  [weak, short of breath, gasping, air, Blount's...
# 36                                                 []
# 37  [weird sensation, weird spot, weakness in my l...
# 38  [Joey's illness, highly invasive and painful m...
# 39  [Late Stage Neurological Lyme Disease, Lyme di...
# 40  [chronic liver disease, biliary atresia, compl...
# 41               [lazy eye, malignant retinoblastoma]
# 42  [stage 4 terminal cancer, blood cancer, Walden...
# 43  [panic of throwing, depression, extremely low ...
# 44  [primary sclerosing cholangitis, damage to liver]
#
#                                               new_doc  \
# 0
# 1      infections and fevers and clinic's septic tank
# 2                      acute neurological dysfunction
# 3   sleep apnea and borderline diabetic and it.The...
# 4   pressure on brain and basically BORG and strok...
# 5                        Acute Lymphoblastic Leukemia
# 6   Stage 4 Undifferentiated Cancer and mass betwe...
# 7                      badly injured and unresponsive
# 8                             AML Leukemia and cancer
# 9
# 10  infantile Scoliosis and recent growth spurt an...
# 11  persistent headache and little slow and wobbly...
# 12  overwhelming obstacles and incurable cancer an...
# 13  Amyotrophic Lateral Sclerosis and ALS and perm...
# 14    severe headache and headache and brain aneurysm
# 15
# 16  MDA and Duchenne Muscular Dystrophy and muscle...
# 17  very badly burned and 2nd degree burns on face...
# 18  swollen arm and blood clot near heart and bloo...
# 19  retinopathy of prematurity and eye cancer in r...
# 20  respiratory failure and lung damage and breast...
# 21                                 breathing problems
# 22  pain and some numbness and infection and infec...
# 23  cancer and wicked illness and illness and noti...
# 24  PAY DECREASE and then Doug's surgical injury a...
# 25                                 biggest sweetheart
# 26  Cystic Fibrosis and genetic disease and CF and...
# 27  mass on Right Frontal Lobe and cyst and cyst a...
# 28  Cancer and cancer and endometrial cancer and a...
# 29  fixed and Cancer and Animales Atenas and cervi...
# 30  complications and infected kidney stone and in...
# 31                                 spinal cord damage
# 32  Esophageal cancer and Thoracotomy and esophage...
# 33  severe scoliosis and many complications and ad...
# 34  Neuropathy of Feet and Extremely Painful Condi...
# 35  weak and short of breath and gasping and air a...
# 36
# 37  weird sensation and weird spot and weakness in...
# 38  Joey's illness and highly invasive and painful...
# 39  Late Stage Neurological Lyme Disease and Lyme ...
# 40  chronic liver disease and biliary atresia and ...
# 41              lazy eye and malignant retinoblastoma
# 42  stage 4 terminal cancer and blood cancer and W...
# 43  panic of throwing and depression and extremely...
# 44  primary sclerosing cholangitis and damage to l...
#
#                                                entity  \
# 0                                                  []
# 1   [{'sentence': '0', 'all_k_distances': '0.0000:...
# 2   [{'sentence': '0', 'all_k_distances': '1.0869:...
# 3   [{'sentence': '0', 'all_k_distances': '0.2354:...
# 4   [{'sentence': '0', 'all_k_distances': '0.9995:...
# 5   [{'sentence': '0', 'all_k_distances': '0.3392:...
# 6   [{'sentence': '0', 'all_k_distances': '0.9471:...
# 7   [{'sentence': '0', 'all_k_distances': '1.3075:...
# 8   [{'sentence': '0', 'all_k_distances': '0.9312:...
# 9                                                  []
# 10  [{'sentence': '0', 'all_k_distances': '0.6102:...
# 11  [{'sentence': '0', 'all_k_distances': '0.5283:...
# 12  [{'sentence': '0', 'all_k_distances': '1.4830:...
# 13  [{'sentence': '0', 'all_k_distances': '0.0000:...
# 14  [{'sentence': '0', 'all_k_distances': '0.4814:...
# 15                                                 []
# 16  [{'sentence': '0', 'all_k_distances': '0.4005:...
# 17  [{'sentence': '0', 'all_k_distances': '1.4845:...
# 18  [{'sentence': '0', 'all_k_distances': '1.1700:...
# 19  [{'sentence': '0', 'all_k_distances': '0.2084:...
# 20  [{'sentence': '0', 'all_k_distances': '0.4833:...
# 21  [{'sentence': '0', 'all_k_distances': '0.8081:...
# 22  [{'sentence': '0', 'all_k_distances': '0.4000:...
# 23  [{'sentence': '0', 'all_k_distances': '0.5048:...
# 24  [{'sentence': '0', 'all_k_distances': '1.6219:...
# 25                                                 []
# 26  [{'sentence': '0', 'all_k_distances': '0.2354:...
# 27  [{'sentence': '0', 'all_k_distances': '0.9284:...
# 28  [{'sentence': '0', 'all_k_distances': '0.5340:...
# 29  [{'sentence': '0', 'all_k_distances': '0.7717:...
# 30  [{'sentence': '0', 'all_k_distances': '0.6973:...
# 31  [{'sentence': '0', 'all_k_distances': '0.7777:...
# 32  [{'sentence': '0', 'all_k_distances': '0.2362:...
# 33  [{'sentence': '0', 'all_k_distances': '0.7700:...
# 34  [{'sentence': '0', 'all_k_distances': '0.8209:...
# 35  [{'sentence': '0', 'all_k_distances': '0.6559:...
# 36                                                 []
# 37  [{'sentence': '0', 'all_k_distances': '0.6836:...
# 38                                                 []
# 39  [{'sentence': '0', 'all_k_distances': '0.8475:...
# 40  [{'sentence': '0', 'all_k_distances': '0.3720:...
# 41  [{'sentence': '0', 'all_k_distances': '0.8672:...
# 42  [{'sentence': '0', 'all_k_distances': '0.9432:...
# 43  [{'sentence': '0', 'all_k_distances': '1.2027:...
# 44  [{'sentence': '0', 'all_k_distances': '0.0000:...
#
#                                        scores_level_2  \
# 0                                                 NaN
# 1   {'HIV/AIDS': 1.0, 'No specific choices': 0.667...
# 2                                                  {}
# 3   {'Coronary artery disease': 0.6930175191174569...
# 4                      {'Stroke': 0.3680634268846233}
# 5     {'Hematologic malignancies': 0.712339966848073}
# 6   {'Coronary artery disease': 0.6703200460356393...
# 7        {'No specific choices': 0.12176041214231789}
# 8             {'Other neoplasms': 0.9977068184972714}
# 9                                                 NaN
# 10  {'No specific choices': 0.28633294554262484, '...
# 11  {'COPD': 0.4147414354642586, 'Coronary artery ...
# 12  {'COPD': 0.5786253932514488, 'No specific choi...
# 13  {'Neurodenerative diseases': 1.0, 'No specific...
# 14  {'Other neurologic disorders': 1.6179177011824...
# 15                                                NaN
# 16  {'Other genitourinary disorders': 0.5203779003...
# 17  {'Other injuries and external causes': 0.57816...
# 18  {'Other injuries and external causes': 0.31036...
# 19  {'No specific choices': 1.3250769053433666, 'O...
# 20  {'No specific choices': 1.511530933655386, 'Ot...
# 21        {'No specific choices': 0.4457041000263628}
# 22  {'Coronary artery disease': 2.6812801841425573...
# 23  {'No specific choices': 1.9111890293434775, 'O...
# 24            {'Other neoplasms': 0.1975230485363839}
# 25                                                NaN
# 26  {'Liver diseases': 0.8407171511618813, 'Other ...
# 27  {'Brain cancer': 0.3951855016064014, 'No speci...
# 28  {'No specific choices': 0.47792569899787096, '...
# 29  {'Breast cancer': 0.3063276494612982, 'No spec...
# 30  {'Other genitourinary disorders': 1.3377056991...
# 31  {'Other neurologic disorders': 0.4594615585452...
# 32  {'Diabetes': 0.3233241172207592, 'Other gastro...
# 33  {'Other injuries and external causes': 0.48388...
# 34  {'Other genitourinary disorders': 0.3943564828...
# 35  {'No specific choices': 1.4956992471054047, 'O...
# 36                                                NaN
# 37  {'Coronary artery disease': 0.6703200460356393...
# 38                                                NaN
# 39  {'No specific choices': 1.1141291030169809, 'O...
# 40  {'No specific choices': 0.39692814882588245, '...
# 41       {'No specific choices': 0.42012625740948306}
# 42  {'Colorectal cancer': 0.3893798241682476, 'Hem...
# 43  {'No specific choices': 0.34850594155102105, '...
# 44  {'No specific choices': 0.5083932584913179, 'O...
#
#                                        scores_level_1  \
# 0                                                 NaN
# 1   {'Infections': 1.0, 'Musculoskeletal diseases'...
# 2                                                  {}
# 3   {'Cardiovascular diseases': 0.6930175191174569...
# 4     {'Cardiovascular diseases': 0.3680634268846233}
# 5                    {'Neoplasms': 0.712339966848073}
# 6   {'Cardiovascular diseases': 0.6703200460356393...
# 7   {'Other noncommunicable diseases': 0.121760412...
# 8                   {'Neoplasms': 0.9977068184972714}
# 9                                                 NaN
# 10  {'Musculoskeletal diseases': 0.936692714957552...
# 11  {'Cardiovascular diseases': 2.6019027951298668...
# 12  {'Endocrine diseases': 1.1717959801915936, 'In...
# 13  {'Chromosomal, congenital, and perinatal disor...
# 14  {'Cardiovascular diseases': 0.6986537569695124...
# 15                                                NaN
# 16  {'Genitourinary disorders': 0.5203779003009712...
# 17  {'Injuries and external causes': 0.57816679094...
# 18  {'Injuries and external causes': 0.31036694126...
# 19  {'Neoplasms': 0.8250332493762969, 'Nervous sys...
# 20  {'Cardiovascular diseases': 0.5641133908979816...
# 21                {'Nonspecific': 0.4457041000263628}
# 22  {'Cardiovascular diseases': 2.6812801841425573...
# 23  {'Cardiovascular diseases': 0.4118483829132257...
# 24                  {'Neoplasms': 0.1975230485363839}
# 25                                                NaN
# 26  {'Endocrine diseases': 1.6568272914393787, 'Ga...
# 27  {'Genitourinary disorders': 1.3294258809241817...
# 28  {'Gastrointestinal diseases': 0.38832991665595...
# 29  {'Chromosomal, congenital, and perinatal disor...
# 30  {'Genitourinary disorders': 1.3377056991071727...
# 31   {'Nervous system diseases': 0.45946155854523124}
# 32  {'Endocrine diseases': 0.3233241172207592, 'Ga...
# 33  {'Injuries and external causes': 0.48388887293...
# 34  {'Genitourinary disorders': 0.3943564828274102...
# 35  {'Chromosomal, congenital, and perinatal disor...
# 36                                                NaN
# 37  {'Cardiovascular diseases': 0.6703200460356393...
# 38                                                NaN
# 39  {'Infections': 4.104856803566717, 'Nervous sys...
# 40  {'Chromosomal, congenital, and perinatal disor...
# 41  {'Other noncommunicable diseases': 0.420126257...
# 42  {'Gastrointestinal diseases': 0.57914639051897...
# 43  {'Chromosomal, congenital, and perinatal disor...
# 44  {'Chromosomal, congenital, and perinatal disor...
#
#                                level_2  \
# 0                                  NaN
# 1                             HIV/AIDS
# 2                                  NaN
# 3                  No specific choices
# 4                               Stroke
# 5             Hematologic malignancies
# 6                      Other neoplasms
# 7                  No specific choices
# 8                      Other neoplasms
# 9                                  NaN
# 10     Other musculoskeletal disorders
# 11                 No specific choices
# 12                     Other neoplasms
# 13            Neurodenerative diseases
# 14          Other neurologic disorders
# 15                                 NaN
# 16          Other neurologic disorders
# 17  Other injuries and external causes
# 18  Other injuries and external causes
# 19                 No specific choices
# 20         Other respiratory disorders
# 21                 No specific choices
# 22                    Other infections
# 23                 No specific choices
# 24                     Other neoplasms
# 25                                 NaN
# 26           Other endocrine disorders
# 27       Other genitourinary disorders
# 28                     Other neoplasms
# 29                     Other neoplasms
# 30                    Other infections
# 31          Other neurologic disorders
# 32                     Other neoplasms
# 33     Other musculoskeletal disorders
# 34                    Other infections
# 35                 No specific choices
# 36                                 NaN
# 37          Other neurologic disorders
# 38                                 NaN
# 39                    Other infections
# 40         Other respiratory disorders
# 41                 No specific choices
# 42            Hematologic malignancies
# 43              Other mental disorders
# 44    Other gastrointestinal disorders
#
#                                              level_1  \
# 0                                                NaN
# 1                                         Infections
# 2                                                NaN
# 3                                        Nonspecific
# 4                            Cardiovascular diseases
# 5                                          Neoplasms
# 6                                          Neoplasms
# 7                     Other noncommunicable diseases
# 8                                          Neoplasms
# 9                                                NaN
# 10                          Musculoskeletal diseases
# 11                                       Nonspecific
# 12                                         Neoplasms
# 13  Chromosomal, congenital, and perinatal disorders
# 14                           Nervous system diseases
# 15                                               NaN
# 16                           Nervous system diseases
# 17                      Injuries and external causes
# 18                      Injuries and external causes
# 19                    Other noncommunicable diseases
# 20                              Respiratory diseases
# 21                                       Nonspecific
# 22                                        Infections
# 23                                       Nonspecific
# 24                                         Neoplasms
# 25                                               NaN
# 26                                Endocrine diseases
# 27                           Genitourinary disorders
# 28                                         Neoplasms
# 29                                         Neoplasms
# 30                                        Infections
# 31                           Nervous system diseases
# 32                                         Neoplasms
# 33                          Musculoskeletal diseases
# 34                                        Infections
# 35  Chromosomal, congenital, and perinatal disorders
# 36                                               NaN
# 37                           Nervous system diseases
# 38                                               NaN
# 39                                        Infections
# 40                              Respiratory diseases
# 41                    Other noncommunicable diseases
# 42                                         Neoplasms
# 43   Mental, behavioral, and substance use disorders
# 44                         Gastrointestinal diseases
#
#                                                 merge
# 0                                                 NaN
# 1   {'sentence': {0: '0', 1: '0', 2: '0'}, 'all_k_...
# 2   {'sentence': {0: '0'}, 'all_k_distances': {0: ...
# 3   {'sentence': {0: '0', 1: '0', 2: '0', 3: '0', ...
# 4   {'sentence': {0: '0'}, 'all_k_distances': {0: ...
# 5   {'sentence': {0: '0'}, 'all_k_distances': {0: ...
# 6   {'sentence': {0: '0', 1: '0', 2: '0', 3: '0', ...
# 7   {'sentence': {0: '0', 1: '0'}, 'all_k_distance...
# 8   {'sentence': {0: '0', 1: '0'}, 'all_k_distance...
# 9                                                 NaN
# 10  {'sentence': {0: '0', 1: '0', 2: '0'}, 'all_k_...
# 11  {'sentence': {0: '0', 1: '0', 2: '0', 3: '0', ...
# 12  {'sentence': {0: '0', 1: '0', 2: '0', 3: '0', ...
# 13  {'sentence': {0: '0', 1: '0', 2: '0', 3: '0'},...
# 14  {'sentence': {0: '0', 1: '0', 2: '0'}, 'all_k_...
# 15                                                NaN
# 16  {'sentence': {0: '0', 1: '0', 2: '0', 3: '0', ...
# 17  {'sentence': {0: '0', 1: '0'}, 'all_k_distance...
# 18  {'sentence': {0: '0'}, 'all_k_distances': {0: ...
# 19  {'sentence': {0: '0', 1: '0', 2: '0', 3: '0', ...
# 20  {'sentence': {0: '0', 1: '0', 2: '0', 3: '0', ...
# 21  {'sentence': {0: '0'}, 'all_k_distances': {0: ...
# 22  {'sentence': {0: '0', 1: '0', 2: '0', 3: '0', ...
# 23  {'sentence': {0: '0', 1: '0', 2: '0', 3: '0', ...
# 24  {'sentence': {0: '0'}, 'all_k_distances': {0: ...
# 25                                                NaN
# 26  {'sentence': {0: '0', 1: '0', 2: '0', 3: '0', ...
# 27  {'sentence': {0: '0', 1: '0', 2: '0', 3: '0', ...
# 28  {'sentence': {0: '0', 1: '0', 2: '0', 3: '0', ...
# 29  {'sentence': {0: '0', 1: '0', 2: '0', 3: '0', ...
# 30  {'sentence': {0: '0', 1: '0', 2: '0', 3: '0', ...
# 31  {'sentence': {0: '0'}, 'all_k_distances': {0: ...
# 32  {'sentence': {0: '0', 1: '0', 2: '0', 3: '0'},...
# 33  {'sentence': {0: '0', 1: '0', 2: '0', 3: '0'},...
# 34  {'sentence': {0: '0', 1: '0', 2: '0', 3: '0'},...
# 35  {'sentence': {0: '0', 1: '0', 2: '0', 3: '0', ...
# 36                                                NaN
# 37  {'sentence': {0: '0', 1: '0', 2: '0', 3: '0', ...
# 38                                                NaN
# 39  {'sentence': {0: '0', 1: '0', 2: '0', 3: '0', ...
# 40  {'sentence': {0: '0', 1: '0', 2: '0', 3: '0', ...
# 41  {'sentence': {0: '0'}, 'all_k_distances': {0: ...
# 42  {'sentence': {0: '0', 1: '0', 2: '0'}, 'all_k_...
# 43  {'sentence': {0: '0', 1: '0', 2: '0'}, 'all_k_...
# 44  {'sentence': {0: '0', 1: '0'}, 'all_k_distance...

# %%
r = GetCategoryScoresICD(GetTopICD(ScaleDistance(r_icd)), 'exp_distance')
# lofd = ScaleDistance(GetTopICD(r_icd))
# d = lofd[2]
# df = pd.DataFrame(d['entity'])
# merge = df.merge(ccsr, how='left', left_on='icd_code', right_on='ICD-10-CM CODE')
# d['scores_level_2'] = merge.groupby(['Level 2'])['exp_distance'].sum().to_dict()
# d['scores_level_1'] = merge.groupby(['Level 1'])['exp_distance'].sum().to_dict()
# d

# %%
df = pd.DataFrame(r)
df = df[['url','level_1']]
df = df.fillna('Nonspecific')
df.to_csv('Manual_Review/round 2/icd10_results.csv')

# %%
df = pd.DataFrame(r)

# %%
pd.DataFrame(df[df['url'] == 'https://www.gofundme.com/f/ruths-skin-removal-surgery']['merge'][3])
# Out:
#   sentence                                    all_k_distances  \
# 0        0  0.2354:::0.2392:::0.4844:::0.4850:::0.6236:::0...
# 1        0  0.6295:::0.9365:::1.0293:::1.0695:::1.0695:::1...
# 2        0  0.3667:::0.3738:::0.4356:::0.4426:::0.4599:::0...
# 3        0  0.8906:::0.9239:::0.9440:::0.9641:::0.9660:::0...
# 4        0  0.9552:::0.9614:::0.9834:::0.9952:::1.0155:::1...
# 5        0  0.5398:::0.7773:::1.1480:::1.1891:::1.2313:::1...
# 6        0  0.9205:::0.9503:::0.9519:::0.9660:::0.9872:::1...
# 7        0  0.3732:::0.6706:::1.0615:::1.1091:::1.1145:::1...
# 8        0  0.5481:::0.7347:::0.7394:::1.0962:::1.2554:::1...
#
#               resolved_text             target_text  \
# 0  Sleep apnea, unspecified             sleep apnea
# 1               Prediabetes     borderline diabetic
# 2           Precordial pain             it.The pain
# 3         Pain, unspecified           physical pain
# 4         Pain, unspecified          emotional pain
# 5               Underweight  my extreme weight loss
# 6           Estrogen excess             excess skin
# 7               Underweight     extreme weight loss
# 8                  Parosmia                 changes
#
#                                    all_k_confidences distance  \
# 0  0.0839:::0.0836:::0.0654:::0.0654:::0.0569:::0...   0.2354
# 1  0.0795:::0.0585:::0.0533:::0.0512:::0.0512:::0...   0.6295
# 2  0.0477:::0.0474:::0.0445:::0.0442:::0.0435:::0...   0.3667
# 3  0.0456:::0.0441:::0.0432:::0.0423:::0.0423:::0...   0.8906
# 4  0.0449:::0.0447:::0.0437:::0.0432:::0.0423:::0...   0.9552
# 5  0.0817:::0.0644:::0.0445:::0.0427:::0.0409:::0...   0.5398
# 6  0.0470:::0.0456:::0.0455:::0.0449:::0.0440:::0...   0.9205
# 7  0.0895:::0.0665:::0.0450:::0.0429:::0.0427:::0...   0.3732
# 8  0.0858:::0.0712:::0.0709:::0.0496:::0.0423:::0...   0.5481
#
#                                    all_k_resolutions confidence chunk  \
# 0  Sleep apnea, unspecified:::Other sleep apnea::...     0.0839     0
# 1  Prediabetes:::Borderline personality disorder:...     0.0795     1
# 2  Precordial pain:::Pain, unspecified:::Cervical...     0.0477     2
# 3  Pain, unspecified:::Age-related physical debil...     0.0456     3
# 4  Pain, unspecified:::Emotional lability:::Chron...     0.0449     4
# 5  Underweight:::Abnormal weight loss:::Bariatric...     0.0817     5
# 6  Estrogen excess:::Cutaneous mastocytosis:::And...     0.0470     6
# 7  Underweight:::Abnormal weight loss:::Bariatric...     0.0895     7
# 8  Parosmia:::Unspecified skin changes:::Other sk...     0.0858     8
#
#                                        all_k_results                   token  \
# 0  G4730:::G4739:::G4731:::R092:::P283:::G4737:::...             sleep apnea
# 1  R7303:::F603:::A303:::A304:::A302:::E71121:::E...     borderline diabetic
# 2  R072:::R52:::M542:::G8922:::G8912:::N644:::R14...             it.The pain
# 3  R52:::R54:::G8922:::M542:::G8912:::R072:::R103...           physical pain
# 4  R52:::R4586:::G8922:::G8912:::M542:::R1031:::R...          emotional pain
# 5  R636:::R634:::O99845:::R635:::O99842:::Z595:::...  my extreme weight loss
# 6  E280:::D4701:::E281:::H5112:::E875:::R200:::I7...             excess skin
# 7  R636:::R634:::O99845:::R635:::Z595:::R29890:::...     extreme weight loss
# 8  R431:::R239:::R238:::R234:::M9120:::F0390:::H0...                 changes
#
#   icd_code  inv_distance  exp_distance ICD-10-CM CODE  \
# 0    G4730      4.248088      0.790255          G4730
# 1    R7303      1.588562      0.532858          R7303
# 2     R072      2.727025      0.693018           R072
# 3      R52      1.122839      0.410409            R52
# 4      R52      1.046901      0.384735            R52
# 5     R636      1.852538      0.582865           R636
# 6     E280      1.086366      0.398320           E280
# 7     R636      2.679528      0.688528           R636
# 8     R431      1.824485      0.578047           R431
#
#   ICD-10-CM CODE DESCRIPTION  \
# 0   Sleep apnea, unspecified
# 1                Prediabetes
# 2            Precordial pain
# 3          Pain, unspecified
# 4          Pain, unspecified
# 5                Underweight
# 6            Estrogen excess
# 7                Underweight
# 8                   Parosmia
#
#                                              Level 3  \
# 0                               Sleep wake disorders
# 1                Abnormal findings without diagnosis
# 2                             Nonspecific chest pain
# 3                   Other general signs and symptoms
# 4                   Other general signs and symptoms
# 5                   Other general signs and symptoms
# 6  Other specified and unspecified endocrine diso...
# 7                   Other general signs and symptoms
# 8                  Nervous system signs and symptoms
#
#                       Level 2                  Level 1
# 0  Other neurologic disorders  Nervous system diseases
# 1         No specific choices              Nonspecific
# 2     Coronary artery disease  Cardiovascular diseases
# 3         No specific choices              Nonspecific
# 4         No specific choices              Nonspecific
# 5         No specific choices              Nonspecific
# 6   Other endocrine disorders       Endocrine diseases
# 7         No specific choices              Nonspecific
# 8         No specific choices              Nonspecific

# %% [markdown]
# #### Athena pipeline

# %%
r = AthenaToCategoryScores(MergeAthena(ScaleDistance(r_athena)), 'inv_distance')

# %%
df = pd.DataFrame(r)
df = df[['url','level_1']]
df = df.fillna('Nonspecific')
df.to_csv('Manual_Review/round 2/athena_results_inv.csv')

# %% [markdown]
# #### SNOMED pipeline

# %%
#r = SnomedToCategoryScores(ScaleDistance(GetTopSnomed(r_snomed)), 'exp_distance')

# %% [markdown]
# # Spacy NEr

# %%
df = pd.read_csv('Comparing algorithms/round 2 campaign terms/round_2_ner_disease_cui_code.csv')

# %%
df = df[df['sab'] == 'ICD10CM']

# %%
def GetIdxMax(df):
    idx_max = []
    for url in df['url'].unique():
        d = copy.deepcopy(df)
        d = d[d['url'] == url]
        for text in d['text'].unique():
            f = copy.deepcopy(d)
            f = f[f['text'] == text]
            idx_max.append(f['score'].idxmax())
    return idx_max

# %%
a = df[df['url'] == 'https://www.gofundme.com/f/wesley-needs-a-liver-transplant']

# %%
l = GetIdxMax(df)

# %%
df.loc[l].head()
# Out:
#                                                     url                 text  \
# 4     https://www.gofundme.com/f/help-piper-afford-a...            arthritis
# 15                https://www.gofundme.com/f/tangopolly            arthritis
# 6037              https://www.gofundme.com/f/tangopolly                 COPD
# 6240              https://www.gofundme.com/f/tangopolly  respiratory failure
# 6318              https://www.gofundme.com/f/tangopolly        breast cancer
#
#         label  start_char  end_char  score       cui lang ts       lui  \
# 4     DISEASE           0         9    1.0  C0003864  ENG  P  L0003864
# 15    DISEASE         110       119    1.0  C0003864  ENG  P  L0003864
# 6037  DISEASE         154       158    1.0  C0024117  ENG  P  L0498186
# 6240  DISEASE           0        19    1.0  C1145670  ENG  S  L0834696
# 6318  DISEASE          34        47    1.0  C0006142  ENG  P  L0531189
#
#           sab tty code
# 4     ICD10CM  ET  M19
# 15    ICD10CM  ET  M19
# 6037  ICD10CM  ET  J44
# 6240  ICD10CM  AB  J96
# 6318  ICD10CM  AB  C50

# %%
ccsr['ICD-10-CM CODE'] = [x.replace('.','')[:3] for x in ccsr['ICD-10-CM CODE']]

# %%
ccsr = ccsr.drop_duplicates('ICD-10-CM CODE')

# %%
m = df.loc[l].merge(ccsr, how='left', left_on='code', right_on='ICD-10-CM CODE')

# %%
m.head()
# Out:
#                                                  url                 text  \
# 0  https://www.gofundme.com/f/help-piper-afford-a...            arthritis
# 1              https://www.gofundme.com/f/tangopolly            arthritis
# 2              https://www.gofundme.com/f/tangopolly                 COPD
# 3              https://www.gofundme.com/f/tangopolly  respiratory failure
# 4              https://www.gofundme.com/f/tangopolly        breast cancer
#
#      label  start_char  end_char  score       cui lang ts       lui      sab  \
# 0  DISEASE           0         9    1.0  C0003864  ENG  P  L0003864  ICD10CM
# 1  DISEASE         110       119    1.0  C0003864  ENG  P  L0003864  ICD10CM
# 2  DISEASE         154       158    1.0  C0024117  ENG  P  L0498186  ICD10CM
# 3  DISEASE           0        19    1.0  C1145670  ENG  S  L0834696  ICD10CM
# 4  DISEASE          34        47    1.0  C0006142  ENG  P  L0531189  ICD10CM
#
#   tty code ICD-10-CM CODE                         ICD-10-CM CODE DESCRIPTION  \
# 0  ET  M19            M19             Primary osteoarthritis, right shoulder
# 1  ET  M19            M19             Primary osteoarthritis, right shoulder
# 2  ET  J44            J44  Chronic obstructive pulmonary disease with acu...
# 3  AB  J96            J96  Acute respiratory failure, unspecified whether...
# 4  AB  C50            C50  Malignant neoplasm of nipple and areola, right...
#
#                                              Level 3  \
# 0                                     Osteoarthritis
# 1                                     Osteoarthritis
# 2  Chronic obstructive pulmonary disease and bron...
# 3         Respiratory failure; insufficiency; arrest
# 4                    Breast cancer - all other types
#
#                            Level 2                   Level 1
# 0  Other musculoskeletal disorders  Musculoskeletal diseases
# 1  Other musculoskeletal disorders  Musculoskeletal diseases
# 2                             COPD      Respiratory diseases
# 3      Other respiratory disorders      Respiratory diseases
# 4                    Breast cancer                 Neoplasms

# %%
def GetCat(df):
    u = []
    r = []
    for url in df['url'].unique():
        d = copy.deepcopy(df)
        d = d[d['url'] == url]
        cat = d.groupby(['Level 1'])['score'].sum().sort_values(ascending=False).index[0]
        u.append(url)
        r.append(cat)
    res = pd.DataFrame({'url':u, 'cat':r})
    return res

# %%
m[m['url'] == 'https://www.gofundme.com/f/k9v7rvss']
# Out:
#                                     url  text    label  start_char  end_char  \
# 91  https://www.gofundme.com/f/k9v7rvss  cyst  DISEASE          36        40
#
#        score       cui lang ts       lui      sab tty code ICD-10-CM CODE  \
# 91  0.820251  C0494710  ENG  S  L0804366  ICD10CM  PT  K09            K09
#
#          ICD-10-CM CODE DESCRIPTION                         Level 3  \
# 91  Developmental odontogenic cysts  Disorders of teeth and gingiva
#
#                              Level 2                    Level 1
# 91  Other gastrointestinal disorders  Gastrointestinal diseases

# %%
d = GetCat(m)

# %%
man = pd.read_csv('Manual_review/round 2/merged_for_python.csv')

# %%
m = man.merge(d, on='url')

# %%
m.to_csv('cui_merged.csv')

# %% [markdown]
# # --------
# # OLD CODE
# # --------

# %% [markdown]
# ### Import json data

# %%
path_to_json = 'spark/comparing_heart'
json_files = ['spark/comparing_heart/' + pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]

temp = pd.DataFrame()

for file in json_files:
    data = pd.read_json(file, lines=False)
    data['model'] = [file.split("/")[2].split(".")[0] for x in range(0, len(data))]
    temp = temp.append(data, ignore_index = True)

# %% [markdown]
# # ICD10

# %%
clin = temp[temp['model'] == 'ner_jsl_icd10']

clin['icd_code'] = [x.split(':::')[0] for x in clin['all_k_results']]

clin['inv_dist'] = 1/clin['distance']

clin['inv_dist'] = [x if x < 1000000000 else 100 for x in clin['inv_dist']]

merge = clin.merge(ccsr, how='left', left_on='icd_code', right_on='ICD-10-CM Code')

merge = merge[merge['Inpatient Default CCSR (Y/N/X)'] == "Y"]

merge['cat'] = [x[:3] for x in merge['CCSR Category']]

merge.groupby(['cat'])['inv_dist'].sum()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# cat
# MAL    2.752546
# Name: inv_dist, dtype: float64

# %% [markdown]
# # ATHENA

# %%
clin = temp[temp['model'] == 'ner_jsl_athena']

clin['inv_dist'] = 1/clin['distance']

clin['inv_dist'] = [x if x < 1000000000 else 100 for x in clin['inv_dist']]

merged = clin.merge(athena, how='left', left_on='all_k_results', right_on='concept_id')

merged = merged[merged['vocabulary_id'] == "SNOMED"]

merged['concept_code'] = merged['concept_code'].astype(int)

merge2 = merged.merge(snomed, how='left', left_on='concept_code', right_on='referencedComponentId')

merge2 = merge2[merge2['mapGroup'] == 1]
#merge2 = merge2[merge2['mapRule'] == 'OTHERWISE TRUE']

merge2['mapTarget'] = [x.replace('.','') if x != None else x for x in merge2['mapTarget']]

merge2 = merge2.dropna(subset=['mapTarget'])

merge3 = merge2.merge(ccsr, how='left', left_on='mapTarget', right_on='ICD-10-CM Code')

merge3 = merge3[merge3['Inpatient Default CCSR (Y/N/X)'] == "Y"]

merge3['cat'] = [x[:3] for x in merge3['CCSR Category']]

merge3.groupby(['cat'])['inv_dist'].sum()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# cat
# MAL    1.980983
# Name: inv_dist, dtype: float64

# %% [markdown]
# # SNOMED

# %%
clin = temp[temp['model'] == 'ner_jsl_snomed']

clin['inv_dist'] = 1/clin['distance']

clin['inv_dist'] = [x if x < 1000000000 else 100 for x in clin['inv_dist']]

clin['snomed_code'] = [x.split(':::')[0] for x in clin['all_k_results']]

clin['snomed_code'] = clin['snomed_code'].astype(int)

merge2 = clin.merge(snomed, how='left', left_on='snomed_code', right_on='referencedComponentId')

merge2 = merge2[merge2['mapGroup'] == 1]
#merge2 = merge2[merge2['mapRule'] == 'OTHERWISE TRUE']

merge2['mapTarget'] = [x.replace('.','') if x != None else x for x in merge2['mapTarget']]

merge2 = merge2.dropna(subset=['mapTarget'])

merge3 = merge2.merge(ccsr, how='left', left_on='mapTarget', right_on='ICD-10-CM Code')

merge3 = merge3[merge3['Inpatient Default CCSR (Y/N/X)'] == "Y"]

merge3['cat'] = [x[:3] for x in merge3['CCSR Category']]

merge3.groupby(['cat'])['inv_dist'].sum()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# cat
# MAL    1.499925
# Name: inv_dist, dtype: float64

# %%
ccsr
# Out:
#       ICD-10-CM CODE                         ICD-10-CM CODE DESCRIPTION  \
# 0               I200                                    Unstable angina
# 1               I201              Angina pectoris with documented spasm
# 2               I208                     Other forms of angina pectoris
# 3               I209                       Angina pectoris, unspecified
# 4              I2101  ST elevation (STEMI) myocardial infarction inv...
# ...              ...                                                ...
# 73200           Z990                            Dependence on aspirator
# 73201           Z992                       Dependence on renal dialysis
# 73202           Z993                           Dependence on wheelchair
# 73203          Z9981                  Dependence on supplemental oxygen
# 73204          Z9989  Dependence on other enabling machines and devices
#
#                                                 Level 3  \
# 0      Coronary atherosclerosis and other heart disease
# 1      Coronary atherosclerosis and other heart disease
# 2      Coronary atherosclerosis and other heart disease
# 3      Coronary atherosclerosis and other heart disease
# 4                           Acute myocardial infarction
# ...                                                 ...
# 73200                                               NaN
# 73201                                               NaN
# 73202                                               NaN
# 73203                                               NaN
# 73204                                               NaN
#
#                        Level 2                  Level 1
# 0      Coronary artery disease  Cardiovascular diseases
# 1      Coronary artery disease  Cardiovascular diseases
# 2      Coronary artery disease  Cardiovascular diseases
# 3      Coronary artery disease  Cardiovascular diseases
# 4      Coronary artery disease  Cardiovascular diseases
# ...                        ...                      ...
# 73200                      NaN                      NaN
# 73201                      NaN                      NaN
# 73202                      NaN                      NaN
# 73203                      NaN                      NaN
# 73204                      NaN                      NaN
#
# [73205 rows x 5 columns]

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
ccsr = pd.read_excel('Manual_Review/disease_hierarchy_11.30.2020.xlsx')

# %%
ccsr['ICD-10-CM CODE DESCRIPTION'] = ccsr['ICD-10-CM CODE DESCRIPTION'].str.lower()

# %%
process.extractOne("scoliosis", ccsr['ICD-10-CM CODE DESCRIPTION'].tolist())
# Out:
# ('congenital scoliosis due to congenital bony malformation', 90)

# %%
nchar = [len(x) for x in ccsr['ICD-10-CM CODE']]

# %%
pd.Series(nchar).value_counts()
# Out:
# 7    50730
# 6     9989
# 5     6710
# 4     5547
# 3      229
# dtype: int64

# %%
[x for x in ccsr['ICD-10-CM CODE']]
# Out:
# ['I200',
#  'I201',
#  'I208',
#  'I209',
#  'I2101',
#  'I2102',
#  'I2109',
#  'I2111',
#  'I2119',
#  'I2121',
#  'I2129',
#  'I213',
#  'I214',
#  'I219',
#  'I21A1',
#  'I21A9',
#  'I220',
#  'I221',
#  'I222',
#  'I228',
#  'I229',
#  'I230',
#  'I231',
#  'I232',
#  'I233',
#  'I234',
#  'I235',
#  'I236',
#  'I237',
#  'I238',
#  'I240',
#  'I241',
#  'I248',
#  'I249',
#  'I2510',
#  'I25110',
#  'I25111',
#  'I25118',
#  'I25119',
#  'I252',
#  'I255',
#  'I256',
#  'I25700',
#  'I25701',
#  'I25708',
#  'I25709',
#  'I25710',
#  'I25711',
#  'I25718',
#  'I25719',
#  'I25720',
#  'I25721',
#  'I25728',
#  'I25729',
#  'I25730',
#  'I25731',
#  'I25738',
#  'I25739',
#  'I25750',
#  'I25751',
#  'I25758',
#  'I25759',
#  'I25760',
#  'I25761',
#  'I25768',
#  'I25769',
#  'I25790',
#  'I25791',
#  'I25798',
#  'I25799',
#  'I25810',
#  'I25811',
#  'I25812',
#  'I2589',
#  'I259',
#  'R072',
#  'R0789',
#  'R079',
#  'I0981',
#  'I110',
#  'I130',
#  'I501',
#  'I5020',
#  'I5021',
#  'I5022',
#  'I5023',
#  'I5030',
#  'I5031',
#  'I5032',
#  'I5033',
#  'I5040',
#  'I5041',
#  'I5042',
#  'I5043',
#  'I50810',
#  'I50811',
#  'I50812',
#  'I50813',
#  'I50814',
#  'I5082',
#  'I5083',
#  'I5084',
#  'I5089',
#  'I509',
#  'A3282',
#  'A3681',
#  'A381',
#  'A3950',
#  'A3951',
#  'A3952',
#  'A3953',
#  'B2682',
#  'B3320',
#  'B3321',
#  'B3322',
#  'B3323',
#  'B3324',
#  'B376',
#  'B5881',
#  'I00',
#  'I010',
#  'I011',
#  'I012',
#  'I018',
#  'I019',
#  'I020',
#  'I029',
#  'I050',
#  'I051',
#  'I052',
#  'I058',
#  'I059',
#  'I060',
#  'I061',
#  'I062',
#  'I068',
#  'I069',
#  'I070',
#  'I071',
#  'I072',
#  'I078',
#  'I079',
#  'I080',
#  'I081',
#  'I082',
#  'I083',
#  'I088',
#  'I089',
#  'I090',
#  'I091',
#  'I092',
#  'I0989',
#  'I099',
#  'I10',
#  'I119',
#  'I150',
#  'I151',
#  'I152',
#  'I158',
#  'I159',
#  'I160',
#  'I161',
#  'I169',
#  'I253',
#  'I2541',
#  'I2542',
#  'I2602',
#  'I2609',
#  'I2692',
#  'I2693',
#  'I2694',
#  'I2699',
#  'I270',
#  'I271',
#  'I272',
#  'I2720',
#  'I2721',
#  'I2722',
#  'I2723',
#  'I2724',
#  'I2729',
#  'I2781',
#  'I2782',
#  'I2783',
#  'I2789',
#  'I279',
#  'I280',
#  'I281',
#  'I288',
#  'I289',
#  'I300',
#  'I301',
#  'I308',
#  'I309',
#  'I310',
#  'I311',
#  'I312',
#  'I313',
#  'I318',
#  'I319',
#  'I330',
#  'I339',
#  'I340',
#  'I341',
#  'I342',
#  'I348',
#  'I349',
#  'I350',
#  'I351',
#  'I352',
#  'I358',
#  'I359',
#  'I360',
#  'I361',
#  'I362',
#  'I368',
#  'I369',
#  'I370',
#  'I371',
#  'I372',
#  'I378',
#  'I379',
#  'I38',
#  'I400',
#  'I401',
#  'I408',
#  'I409',
#  'I420',
#  'I421',
#  'I422',
#  'I423',
#  'I424',
#  'I425',
#  'I426',
#  'I428',
#  'I429',
#  'I440',
#  'I441',
#  'I442',
#  'I4430',
#  'I4439',
#  'I444',
#  'I445',
#  'I4460',
#  'I4469',
#  'I447',
#  'I450',
#  'I4510',
#  'I4519',
#  'I452',
#  'I453',
#  'I454',
#  'I455',
#  'I456',
#  'I4581',
#  'I4589',
#  'I459',
#  'I469',
#  'I470',
#  'I471',
#  'I472',
#  'I479',
#  'I480',
#  'I481',
#  'I4811',
#  'I4819',
#  'I482',
#  'I4820',
#  'I4821',
#  'I483',
#  'I484',
#  'I4891',
#  'I4892',
#  'I4901',
#  'I4902',
#  'I491',
#  'I492',
#  'I493',
#  'I4940',
#  'I4949',
#  'I495',
#  'I498',
#  'I499',
#  'I510',
#  'I511',
#  'I512',
#  'I513',
#  'I514',
#  'I515',
#  'I517',
#  'I5181',
#  'I5189',
#  'I519',
#  'I670',
#  'I674',
#  'I700',
#  'I701',
#  'I70201',
#  'I70202',
#  'I70203',
#  'I70208',
#  'I70209',
#  'I70211',
#  'I70212',
#  'I70213',
#  'I70218',
#  'I70219',
#  'I70221',
#  'I70222',
#  'I70223',
#  'I70228',
#  'I70229',
#  'I70231',
#  'I70232',
#  'I70233',
#  'I70234',
#  'I70235',
#  'I70238',
#  'I70239',
#  'I70241',
#  'I70242',
#  'I70243',
#  'I70244',
#  'I70245',
#  'I70248',
#  'I70249',
#  'I7025',
#  'I70261',
#  'I70262',
#  'I70263',
#  'I70268',
#  'I70269',
#  'I70291',
#  'I70292',
#  'I70293',
#  'I70298',
#  'I70299',
#  'I70301',
#  'I70302',
#  'I70303',
#  'I70308',
#  'I70309',
#  'I70311',
#  'I70312',
#  'I70313',
#  'I70318',
#  'I70319',
#  'I70321',
#  'I70322',
#  'I70323',
#  'I70328',
#  'I70329',
#  'I70331',
#  'I70332',
#  'I70333',
#  'I70334',
#  'I70335',
#  'I70338',
#  'I70339',
#  'I70341',
#  'I70342',
#  'I70343',
#  'I70344',
#  'I70345',
#  'I70348',
#  'I70349',
#  'I7035',
#  'I70361',
#  'I70362',
#  'I70363',
#  'I70368',
#  'I70369',
#  'I70391',
#  'I70392',
#  'I70393',
#  'I70398',
#  'I70399',
#  'I70401',
#  'I70402',
#  'I70403',
#  'I70408',
#  'I70409',
#  'I70411',
#  'I70412',
#  'I70413',
#  'I70418',
#  'I70419',
#  'I70421',
#  'I70422',
#  'I70423',
#  'I70428',
#  'I70429',
#  'I70431',
#  'I70432',
#  'I70433',
#  'I70434',
#  'I70435',
#  'I70438',
#  'I70439',
#  'I70441',
#  'I70442',
#  'I70443',
#  'I70444',
#  'I70445',
#  'I70448',
#  'I70449',
#  'I7045',
#  'I70461',
#  'I70462',
#  'I70463',
#  'I70468',
#  'I70469',
#  'I70491',
#  'I70492',
#  'I70493',
#  'I70498',
#  'I70499',
#  'I70501',
#  'I70502',
#  'I70503',
#  'I70508',
#  'I70509',
#  'I70511',
#  'I70512',
#  'I70513',
#  'I70518',
#  'I70519',
#  'I70521',
#  'I70522',
#  'I70523',
#  'I70528',
#  'I70529',
#  'I70531',
#  'I70532',
#  'I70533',
#  'I70534',
#  'I70535',
#  'I70538',
#  'I70539',
#  'I70541',
#  'I70542',
#  'I70543',
#  'I70544',
#  'I70545',
#  'I70548',
#  'I70549',
#  'I7055',
#  'I70561',
#  'I70562',
#  'I70563',
#  'I70568',
#  'I70569',
#  'I70591',
#  'I70592',
#  'I70593',
#  'I70598',
#  'I70599',
#  'I70601',
#  'I70602',
#  'I70603',
#  'I70608',
#  'I70609',
#  'I70611',
#  'I70612',
#  'I70613',
#  'I70618',
#  'I70619',
#  'I70621',
#  'I70622',
#  'I70623',
#  'I70628',
#  'I70629',
#  'I70631',
#  'I70632',
#  'I70633',
#  'I70634',
#  'I70635',
#  'I70638',
#  'I70639',
#  'I70641',
#  'I70642',
#  'I70643',
#  'I70644',
#  'I70645',
#  'I70648',
#  'I70649',
#  'I7065',
#  'I70661',
#  'I70662',
#  'I70663',
#  'I70668',
#  'I70669',
#  'I70691',
#  'I70692',
#  'I70693',
#  'I70698',
#  'I70699',
#  'I70701',
#  'I70702',
#  'I70703',
#  'I70708',
#  'I70709',
#  'I70711',
#  'I70712',
#  'I70713',
#  'I70718',
#  'I70719',
#  'I70721',
#  'I70722',
#  'I70723',
#  'I70728',
#  'I70729',
#  'I70731',
#  'I70732',
#  'I70733',
#  'I70734',
#  'I70735',
#  'I70738',
#  'I70739',
#  'I70741',
#  'I70742',
#  'I70743',
#  'I70744',
#  'I70745',
#  'I70748',
#  'I70749',
#  'I7075',
#  'I70761',
#  'I70762',
#  'I70763',
#  'I70768',
#  'I70769',
#  'I70791',
#  'I70792',
#  'I70793',
#  'I70798',
#  'I70799',
#  'I708',
#  'I7090',
#  'I7091',
#  'I7100',
#  'I7101',
#  'I7102',
#  'I7103',
#  'I711',
#  'I712',
#  'I713',
#  'I714',
#  'I715',
#  'I716',
#  'I718',
#  'I719',
#  'I720',
#  'I721',
#  'I722',
#  'I723',
#  'I724',
#  'I725',
#  'I726',
#  'I728',
#  'I729',
#  'I7300',
#  'I7301',
#  'I731',
#  'I7381',
#  'I7389',
#  'I739',
#  'I7401',
#  'I7409',
#  'I7410',
#  'I7411',
#  'I7419',
#  'I742',
#  'I743',
#  'I744',
#  'I745',
#  'I748',
#  'I749',
#  'I75011',
#  'I75012',
#  'I75013',
#  'I75019',
#  'I75021',
#  'I75022',
#  'I75023',
#  'I75029',
#  'I7581',
#  'I7589',
#  'I770',
#  'I771',
#  'I772',
#  'I773',
#  'I774',
#  'I775',
#  'I776',
#  'I7770',
#  'I7771',
#  'I7772',
#  'I7773',
#  'I7774',
#  'I7775',
#  'I7776',
#  'I7777',
#  'I7779',
#  'I77810',
#  'I77811',
#  'I77812',
#  'I77819',
#  'I7789',
#  'I779',
#  'I780',
#  'I781',
#  'I788',
#  'I789',
#  'I8000',
#  'I8001',
#  'I8002',
#  'I8003',
#  'I8010',
#  'I8011',
#  'I8012',
#  'I8013',
#  'I80201',
#  'I80202',
#  'I80203',
#  'I80209',
#  'I80211',
#  'I80212',
#  'I80213',
#  'I80219',
#  'I80221',
#  'I80222',
#  'I80223',
#  'I80229',
#  'I80231',
#  'I80232',
#  'I80233',
#  'I80239',
#  'I80241',
#  'I80242',
#  'I80243',
#  'I80249',
#  'I80251',
#  'I80252',
#  'I80253',
#  'I80259',
#  'I80291',
#  'I80292',
#  'I80293',
#  'I80299',
#  'I803',
#  'I808',
#  'I809',
#  'I81',
#  'I820',
#  'I821',
#  'I82210',
#  'I82211',
#  'I82220',
#  'I82221',
#  'I82290',
#  'I82291',
#  'I823',
#  'I82401',
#  'I82402',
#  'I82403',
#  'I82409',
#  'I82411',
#  'I82412',
#  'I82413',
#  'I82419',
#  'I82421',
#  'I82422',
#  'I82423',
#  'I82429',
#  'I82431',
#  'I82432',
#  'I82433',
#  'I82439',
#  'I82441',
#  'I82442',
#  'I82443',
#  'I82449',
#  'I82451',
#  'I82452',
#  'I82453',
#  'I82459',
#  'I82461',
#  'I82462',
#  'I82463',
#  'I82469',
#  'I82491',
#  'I82492',
#  'I82493',
#  'I82499',
#  'I824Y1',
#  'I824Y2',
#  'I824Y3',
#  'I824Y9',
#  'I824Z1',
#  'I824Z2',
#  'I824Z3',
#  'I824Z9',
#  'I82501',
#  'I82502',
#  'I82503',
#  'I82509',
#  'I82511',
#  'I82512',
#  'I82513',
#  'I82519',
#  'I82521',
#  'I82522',
#  'I82523',
#  'I82529',
#  'I82531',
#  'I82532',
#  'I82533',
#  'I82539',
#  'I82541',
#  'I82542',
#  'I82543',
#  'I82549',
#  'I82551',
#  'I82552',
#  'I82553',
#  'I82559',
#  'I82561',
#  'I82562',
#  'I82563',
#  'I82569',
#  'I82591',
#  'I82592',
#  'I82593',
#  'I82599',
#  'I825Y1',
#  'I825Y2',
#  'I825Y3',
#  'I825Y9',
#  'I825Z1',
#  'I825Z2',
#  'I825Z3',
#  'I825Z9',
#  'I82601',
#  'I82602',
#  'I82603',
#  'I82609',
#  'I82611',
#  'I82612',
#  'I82613',
#  'I82619',
#  'I82621',
#  'I82622',
#  'I82623',
#  'I82629',
#  'I82701',
#  'I82702',
#  'I82703',
#  'I82709',
#  'I82711',
#  'I82712',
#  'I82713',
#  'I82719',
#  'I82721',
#  'I82722',
#  'I82723',
#  'I82729',
#  'I82811',
#  'I82812',
#  'I82813',
#  'I82819',
#  'I82890',
#  'I82891',
#  'I8290',
#  'I8291',
#  'I82A11',
#  'I82A12',
#  'I82A13',
#  'I82A19',
#  'I82A21',
#  'I82A22',
#  'I82A23',
#  'I82A29',
#  'I82B11',
#  'I82B12',
#  'I82B13',
#  'I82B19',
#  'I82B21',
#  'I82B22',
#  'I82B23',
#  'I82B29',
#  'I82C11',
#  'I82C12',
#  'I82C13',
#  'I82C19',
#  'I82C21',
#  'I82C22',
#  'I82C23',
#  'I82C29',
#  'I83001',
#  'I83002',
#  'I83003',
#  'I83004',
#  'I83005',
#  'I83008',
#  'I83009',
#  'I83011',
#  'I83012',
#  'I83013',
#  'I83014',
#  'I83015',
#  'I83018',
#  'I83019',
#  'I83021',
#  'I83022',
#  'I83023',
#  'I83024',
#  'I83025',
#  'I83028',
#  'I83029',
#  'I8310',
#  'I8311',
#  'I8312',
#  'I83201',
#  'I83202',
#  'I83203',
#  'I83204',
#  'I83205',
#  'I83208',
#  'I83209',
#  'I83211',
#  'I83212',
#  'I83213',
#  'I83214',
#  'I83215',
#  'I83218',
#  'I83219',
#  'I83221',
#  'I83222',
#  'I83223',
#  'I83224',
#  'I83225',
#  'I83228',
#  'I83229',
#  'I83811',
#  'I83812',
#  'I83813',
#  'I83819',
#  'I83891',
#  'I83892',
#  'I83893',
#  'I83899',
#  'I8390',
#  'I8391',
#  'I8392',
#  'I8393',
#  'I8500',
#  'I8501',
#  'I8510',
#  'I8511',
#  'I860',
#  'I861',
#  'I862',
#  'I863',
#  'I864',
#  'I868',
#  'I87001',
#  'I87002',
#  'I87003',
#  'I87009',
#  'I87011',
#  'I87012',
#  'I87013',
#  'I87019',
#  'I87021',
#  'I87022',
#  'I87023',
#  'I87029',
#  'I87031',
#  'I87032',
#  'I87033',
#  'I87039',
#  'I87091',
#  'I87092',
#  'I87093',
#  'I87099',
#  'I871',
#  'I872',
#  'I87301',
#  'I87302',
#  'I87303',
#  'I87309',
#  'I87311',
#  'I87312',
#  'I87313',
#  'I87319',
#  'I87321',
#  'I87322',
#  'I87323',
#  'I87329',
#  'I87331',
#  'I87332',
#  'I87333',
#  'I87339',
#  'I87391',
#  'I87392',
#  'I87393',
#  'I87399',
#  'I878',
#  'I879',
#  'I880',
#  'I881',
#  'I888',
#  'I889',
#  'I890',
#  'I891',
#  'I898',
#  'I899',
#  'I950',
#  'I951',
#  'I953',
#  'I9581',
#  'I9589',
#  'I959',
#  'I96',
#  'I970',
#  'I97110',
#  'I97111',
#  'I97120',
#  'I97121',
#  'I97130',
#  'I97131',
#  'I97190',
#  'I97191',
#  'I972',
#  'I973',
#  'I97410',
#  'I97411',
#  'I97418',
#  'I9742',
#  'I9751',
#  'I9752',
#  'I97610',
#  'I97611',
#  'I97618',
#  'I9762',
#  'I97620',
#  'I97621',
#  'I97622',
#  'I97630',
#  'I97631',
#  'I97638',
#  'I97640',
#  'I97641',
#  'I97648',
#  'I97710',
#  'I97711',
#  'I97790',
#  'I97791',
#  'I97810',
#  'I97811',
#  'I97820',
#  'I97821',
#  'I9788',
#  'I9789',
#  'I998',
#  'I999',
#  'J850',
#  'Z45010',
#  'Z45018',
#  'G43601',
#  'G43609',
#  'G43611',
#  'G43619',
#  'I6000',
#  'I6001',
#  'I6002',
#  'I6010',
#  'I6011',
#  'I6012',
#  'I602',
#  'I6020',
#  'I6021',
#  'I6022',
#  'I6030',
#  'I6031',
#  'I6032',
#  'I604',
#  'I6050',
#  'I6051',
#  'I6052',
#  'I606',
#  'I607',
#  'I608',
#  'I609',
#  'I610',
#  'I611',
#  'I612',
#  'I613',
#  'I614',
#  ...]
