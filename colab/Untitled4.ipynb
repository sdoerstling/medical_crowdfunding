# %%
! pip install fastText
# Out:
# ...
#      |████████████████████████████████| 71kB 3.4MB/s
# ...
#   Created wheel for fastText: filename=fasttext-0.9.2-cp36-cp36m-linux_x86_64.whl size=3037894 sha256=3e79e4d5d35bb78d382ae8fefbdc256c6360a30506b50916dfc5a4ba331695b6
#   Stored in directory: /root/.cache/pip/wheels/98/ba/7f/b154944a1cf5a8cee91c154b75231136cc3a3321ab0e30f592
# Successfully built fastText
# ...

# %%
from gensim.models import FastText

# %%
import gensim

model = gensim.models.KeyedVectors.load_word2vec_format('/content/drive/MyDrive/Crowdfunding/bio_embedding_extrinsic.bin', binary=True, unicode_errors='ignore')

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Crowdfunding/mesh.csv')

# %%
! cd drive/

# %%
model['tumor']
# Out:
# array([ 4.87341620e-02, -1.36921257e-01, -3.46930809e-02, -4.46540266e-01,
#        -1.25659883e-01,  5.20311832e-01, -2.32419401e-01, -3.80869240e-01,
#         2.51887202e-01,  4.43460084e-02, -6.04086481e-02, -1.20113924e-01,
#         4.67154205e-01,  2.88617730e-01,  6.40699416e-02, -1.18702315e-01,
#         1.76435769e-01,  3.08620811e-01,  1.26357302e-01, -3.95276994e-01,
#         1.49610601e-02, -2.27921903e-01, -6.03418946e-01, -3.88136245e-02,
#         3.33160520e-01, -2.30510905e-01, -8.85763988e-02,  2.54040331e-01,
#         4.34877127e-01, -4.52466339e-01,  1.60808384e-01,  5.13954341e-01,
#         6.03695691e-01,  6.36247098e-01,  1.22959875e-01,  4.69960541e-01,
#        -2.64691144e-01,  2.64734983e-01, -9.75746289e-03, -2.50855565e-01,
#        -8.85676444e-02, -1.84526127e-02, -4.02975827e-01, -1.98927939e-01,
#        -5.23208201e-01, -4.81167808e-02,  3.78563395e-03,  2.12307535e-02,
# ...
