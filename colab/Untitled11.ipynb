# %%
# !wget https://download.nlm.nih.gov/umls/kss/2020AB/umls-2020AB-full.zip
# Out:
# --2021-01-29 02:57:39--  https://download.nlm.nih.gov/umls/kss/2020AB/umls-2020AB-full.zip
# Resolving download.nlm.nih.gov (download.nlm.nih.gov)... 130.14.16.113, 2607:f220:41e:1016::113
# Connecting to download.nlm.nih.gov (download.nlm.nih.gov)|130.14.16.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uts.nlm.nih.gov/uts/login?service=https%3a%2f%2fdownload.nlm.nih.gov%2fumls%2fkss%2f2020AB%2fumls-2020AB-full.zip [following]
# --2021-01-29 02:57:40--  https://uts.nlm.nih.gov/uts/login?service=https%3a%2f%2fdownload.nlm.nih.gov%2fumls%2fkss%2f2020AB%2fumls-2020AB-full.zip
# Resolving uts.nlm.nih.gov (uts.nlm.nih.gov)... 130.14.16.163, 2607:f220:41e:1016::163
# Connecting to uts.nlm.nih.gov (uts.nlm.nih.gov)|130.14.16.163|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Syntax error in Set-Cookie: HttpOnly;Secure at position 9.
# Length: 2360 (2.3K) [text/html]
# Saving to: ‘umls-2020AB-full.zip’
#
# ...
